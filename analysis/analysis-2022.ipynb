# %% [markdown]
# # Analysis from ENEM microdata for 2022

# %% [markdown]
# ## Import libs

# %%
import pandas as pd
from apyori import apriori

# %% [markdown]
# ## Read microdata file

# %%
data = pd.read_csv('../microdata/microdata-enem-2022.csv', sep=';', encoding='ISO-8859-1')
data
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210057943671    2022               14       M                2
# 1        210057516120    2022               14       M                2
# 2        210057280536    2022                5       F                1
# 3        210055724397    2022                6       M                1
# 4        210055097896    2022                4       M                0
# ...               ...     ...              ...     ...              ...
# 3476100  210056389903    2022                3       M                1
# 3476101  210057205644    2022               14       F                2
# 3476102  210056699189    2022                2       M                1
# 3476103  210056983033    2022                3       M                1
# 3476104  210056307777    2022                2       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 0                  2                 1                1                2
# 1                  1                 1                1               16
# 2                  2                 1                1                2
# 3                  3                 1                1                2
# 4                  3                 1                1                1
# ...              ...               ...              ...              ...
# 3476100            1                 1                2                0
# 3476101            1                 1                2                0
# 3476102            1                 1                2                0
# 3476103            3                 1                2                0
# 3476104            3                 1                2                0
#
#          TP_ESCOLA  ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  \
# 0                1  ...     B     A     A    A     A    A     A     A     A
# 1                1  ...     E     E     B    E     B    B     E     B     E
# 2                1  ...     A     A     A    A     A    A     C     A     A
# 3                1  ...     B     A     A    C     A    A     C     B     B
# 4                1  ...     A     A     A    A     A    A     B     A     A
# ...            ...  ...   ...   ...   ...  ...   ...  ...   ...   ...   ...
# 3476100          2  ...     B     A     B    B     B    A     E     A     A
# 3476101          2  ...     A     A     A    B     A    A     C     A     B
# 3476102          2  ...     B     A     B    C     B    A     E     A     B
# 3476103          3  ...     B     A     B    D     A    A     E     A     B
# 3476104          2  ...     A     A     A    B     A    A     C     A     C
#
#          Q025
# 0           A
# 1           B
# 2           B
# 3           B
# 4           A
# ...       ...
# 3476100     B
# 3476101     B
# 3476102     B
# 3476103     B
# 3476104     B
#
# [3476105 rows x 76 columns]

# %% [markdown]
# ## Select only columns of interest

# %%
interest_columns = [
    'TP_SEXO',
    'TP_ESTADO_CIVIL',
    'TP_COR_RACA',
    'TP_FAIXA_ETARIA',
    'TP_ST_CONCLUSAO',
    'TP_ESCOLA',
    'TP_DEPENDENCIA_ADM_ESC',
    'SG_UF_PROVA',
    'NU_NOTA_CN',
    'NU_NOTA_CH',
    'NU_NOTA_LC',
    'NU_NOTA_MT',
    'NU_NOTA_REDACAO',
    'Q001',
    'Q002',
    'Q006',
    'Q022',
    'Q024',
    'Q025'
]

interest_data = data[interest_columns]

interest_data.head()
# Out:
#   TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_FAIXA_ETARIA  TP_ST_CONCLUSAO  \
# 0       M                2            2               14                1
# 1       M                2            1               14                1
# 2       F                1            2                5                1
# 3       M                1            3                6                1
# 4       M                0            3                4                1
#
#    TP_ESCOLA  TP_DEPENDENCIA_ADM_ESC SG_UF_PROVA  NU_NOTA_CN  NU_NOTA_CH  \
# 0          1                     NaN          DF         NaN         NaN
# 1          1                     NaN          DF         NaN         NaN
# 2          1                     NaN          BA       421.1       546.0
# 3          1                     NaN          ES       490.7       388.6
# 4          1                     NaN          PA         NaN         NaN
#
#    NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002 Q006 Q022 Q024 Q025
# 0         NaN         NaN              NaN    A    A    B    A    A    A
# 1         NaN         NaN              NaN    D    D    Q    E    E    B
# 2       498.8       565.3            760.0    E    F    B    C    A    B
# 3       357.8       416.0            320.0    C    A    A    C    B    B
# 4         NaN         NaN              NaN    D    B    B    B    A    A

# %% [markdown]
# ### Check count for valid values

# %%
interest_data.count()
# Out:
# TP_SEXO                   3476105
# TP_ESTADO_CIVIL           3476105
# TP_COR_RACA               3476105
# TP_FAIXA_ETARIA           3476105
# TP_ST_CONCLUSAO           3476105
# TP_ESCOLA                 3476105
# TP_DEPENDENCIA_ADM_ESC     951944
# SG_UF_PROVA               3476105
# NU_NOTA_CN                2355395
# NU_NOTA_CH                2493442
# NU_NOTA_LC                2493442
# NU_NOTA_MT                2355395
# NU_NOTA_REDACAO           2493442
# Q001                      3476105
# Q002                      3476105
# Q006                      3476105
# Q022                      3476105
# Q024                      3476105
# Q025                      3476105
# dtype: int64

# %% [markdown]
# ## Translate some columns to better readability

# %%
# %run '../scripts/attribute-dictionary.py'

interest_data = interest_data.fillna(value = {"TP_DEPENDENCIA_ADM_ESC": 0})
interest_data = interest_data.replace(dictionary_params)

interest_data.head()
# Out:
#      TP_SEXO                       TP_ESTADO_CIVIL TP_COR_RACA  \
# 0  Masculino  Casado(a) ou mora com companheiro(a)       Preto
# 1  Masculino  Casado(a) ou mora com companheiro(a)      Branco
# 2   Feminino                           Solteiro(a)       Preto
# 3  Masculino                           Solteiro(a)       Pardo
# 4  Masculino           Estado civil: Não informado       Pardo
#
#       TP_FAIXA_ETARIA            TP_ST_CONCLUSAO      TP_ESCOLA  \
# 0  Entre 41 e 45 anos  Já concluí o Ensino Médio  Não Respondeu
# 1  Entre 41 e 45 anos  Já concluí o Ensino Médio  Não Respondeu
# 2  Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 3  Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 4  Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
#
#                      TP_DEPENDENCIA_ADM_ESC          SG_UF_PROVA  NU_NOTA_CN  \
# 0  Dependencia administrativa nao informada  Região Centro-Oeste         NaN
# 1  Dependencia administrativa nao informada  Região Centro-Oeste         NaN
# 2  Dependencia administrativa nao informada      Região Nordeste       421.1
# 3  Dependencia administrativa nao informada       Região Sudeste       490.7
# 4  Dependencia administrativa nao informada         Região Norte         NaN
#
#    NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO  \
# 0         NaN         NaN         NaN              NaN
# 1         NaN         NaN         NaN              NaN
# 2       546.0       498.8       565.3            760.0
# 3       388.6       357.8       416.0            320.0
# 4         NaN         NaN         NaN              NaN
#
#                             Q001                          Q002  \
# 0              Pai nunca estudou             Mãe nunca estudou
# 1    Pai Ensino médio incompleto   Mãe Ensino médio incompleto
# 2      Pai Ensino médio completo        Mãe Graduação completa
# 3  Pai Fundamental II incompleto             Mãe nunca estudou
# 4    Pai Ensino médio incompleto  Mãe Fundamental I incompleto
#
#               Q006             Q022                Q024  \
# 0  Classe Social E  Não tem celular  Não tem computador
# 1  Classe Social A      Tem celular      Tem computador
# 2  Classe Social E      Tem celular  Não tem computador
# 3  Classe Social E      Tem celular      Tem computador
# 4  Classe Social E      Tem celular  Não tem computador
#
#                        Q025
# 0  Não tem internet em casa
# 1      Tem internet em casa
# 2      Tem internet em casa
# 3      Tem internet em casa
# 4  Não tem internet em casa

# %% [markdown]
# ## Remove nil values and creates a new column with the arithmetic average of the grades

# %%
interest_data = interest_data.query("NU_NOTA_CN.notnull() and NU_NOTA_CH.notnull() and NU_NOTA_LC.notnull() and NU_NOTA_MT.notnull() and NU_NOTA_REDACAO.notnull() and TP_ESTADO_CIVIL.notnull() and Q006.notnull() and Q022.notnull() and Q024.notnull() and Q025.notnull()")
interest_data["NU_NOTA_GERAL"] = interest_data[["NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_LC", "NU_NOTA_MT", "NU_NOTA_REDACAO"]].mean(axis=1)

interest_data.head()
# Out:
#       TP_SEXO TP_ESTADO_CIVIL TP_COR_RACA     TP_FAIXA_ETARIA  \
# 2    Feminino     Solteiro(a)       Preto  Entre 17 e 25 anos
# 3   Masculino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 7    Feminino     Solteiro(a)       Preto  Entre 17 e 25 anos
# 9    Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 11   Feminino     Solteiro(a)      Branco  Entre 17 e 25 anos
#
#                                   TP_ST_CONCLUSAO      TP_ESCOLA  \
# 2                       Já concluí o Ensino Médio  Não Respondeu
# 3                       Já concluí o Ensino Médio  Não Respondeu
# 7                       Já concluí o Ensino Médio  Não Respondeu
# 9                       Já concluí o Ensino Médio  Não Respondeu
# 11  Estou cursando e concluirei o Ensino este ano        Privada
#
#                       TP_DEPENDENCIA_ADM_ESC      SG_UF_PROVA  NU_NOTA_CN  \
# 2   Dependencia administrativa nao informada  Região Nordeste       421.1
# 3   Dependencia administrativa nao informada   Região Sudeste       490.7
# 7   Dependencia administrativa nao informada   Região Sudeste       398.1
# 9   Dependencia administrativa nao informada  Região Nordeste       467.5
# 11  Dependencia administrativa nao informada  Região Nordeste       458.7
#
#     NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO  \
# 2        546.0       498.8       565.3            760.0
# 3        388.6       357.8       416.0            320.0
# 7        427.3       400.2       404.9            440.0
# 9        461.0       466.7       435.3            360.0
# 11       539.8       488.2       456.8            940.0
#
#                              Q001                       Q002             Q006  \
# 2       Pai Ensino médio completo     Mãe Graduação completa  Classe Social E
# 3   Pai Fundamental II incompleto          Mãe nunca estudou  Classe Social E
# 7       Pai Ensino médio completo  Mãe Ensino médio completo  Classe Social E
# 9       Pai Ensino médio completo  Mãe Ensino médio completo  Classe Social E
# 11      Pai Ensino médio completo  Mãe Ensino médio completo  Classe Social E
#
#            Q022                Q024                  Q025  NU_NOTA_GERAL
# 2   Tem celular  Não tem computador  Tem internet em casa         558.24
# 3   Tem celular      Tem computador  Tem internet em casa         394.62
# 7   Tem celular  Não tem computador  Tem internet em casa         414.10
# 9   Tem celular  Não tem computador  Tem internet em casa         438.10
# 11  Tem celular  Não tem computador  Tem internet em casa         576.70

# %% [markdown]
# ### Check count for valid values

# %%
interest_data.count()
# Out:
# TP_SEXO                   2344823
# TP_ESTADO_CIVIL           2344823
# TP_COR_RACA               2344823
# TP_FAIXA_ETARIA           2344823
# TP_ST_CONCLUSAO           2344823
# TP_ESCOLA                 2344823
# TP_DEPENDENCIA_ADM_ESC    2344823
# SG_UF_PROVA               2344823
# NU_NOTA_CN                2344823
# NU_NOTA_CH                2344823
# NU_NOTA_LC                2344823
# NU_NOTA_MT                2344823
# NU_NOTA_REDACAO           2344823
# Q001                      2344823
# Q002                      2344823
# Q006                      2344823
# Q022                      2344823
# Q024                      2344823
# Q025                      2344823
# NU_NOTA_GERAL             2344823
# dtype: int64

# %% [markdown]
# ## Calculate Z-SCORE from NU_NOTA_GERAL

# %%
from scipy.stats import zscore

interest_data["Z_SCORE_NOTA"] = zscore(interest_data["NU_NOTA_GERAL"])
interest_data.head()
# Out:
#       TP_SEXO TP_ESTADO_CIVIL TP_COR_RACA     TP_FAIXA_ETARIA  \
# 2    Feminino     Solteiro(a)       Preto  Entre 17 e 25 anos
# 3   Masculino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 7    Feminino     Solteiro(a)       Preto  Entre 17 e 25 anos
# 9    Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 11   Feminino     Solteiro(a)      Branco  Entre 17 e 25 anos
#
#                                   TP_ST_CONCLUSAO      TP_ESCOLA  \
# 2                       Já concluí o Ensino Médio  Não Respondeu
# 3                       Já concluí o Ensino Médio  Não Respondeu
# 7                       Já concluí o Ensino Médio  Não Respondeu
# 9                       Já concluí o Ensino Médio  Não Respondeu
# 11  Estou cursando e concluirei o Ensino este ano        Privada
#
#                       TP_DEPENDENCIA_ADM_ESC      SG_UF_PROVA  NU_NOTA_CN  \
# 2   Dependencia administrativa nao informada  Região Nordeste       421.1
# 3   Dependencia administrativa nao informada   Região Sudeste       490.7
# 7   Dependencia administrativa nao informada   Região Sudeste       398.1
# 9   Dependencia administrativa nao informada  Região Nordeste       467.5
# 11  Dependencia administrativa nao informada  Região Nordeste       458.7
#
#     NU_NOTA_CH  ...  NU_NOTA_MT  NU_NOTA_REDACAO  \
# 2        546.0  ...       565.3            760.0
# 3        388.6  ...       416.0            320.0
# 7        427.3  ...       404.9            440.0
# 9        461.0  ...       435.3            360.0
# 11       539.8  ...       456.8            940.0
#
#                              Q001                       Q002             Q006  \
# 2       Pai Ensino médio completo     Mãe Graduação completa  Classe Social E
# 3   Pai Fundamental II incompleto          Mãe nunca estudou  Classe Social E
# 7       Pai Ensino médio completo  Mãe Ensino médio completo  Classe Social E
# 9       Pai Ensino médio completo  Mãe Ensino médio completo  Classe Social E
# 11      Pai Ensino médio completo  Mãe Ensino médio completo  Classe Social E
#
#            Q022                Q024                  Q025 NU_NOTA_GERAL  \
# 2   Tem celular  Não tem computador  Tem internet em casa        558.24
# 3   Tem celular      Tem computador  Tem internet em casa        394.62
# 7   Tem celular  Não tem computador  Tem internet em casa        414.10
# 9   Tem celular  Não tem computador  Tem internet em casa        438.10
# 11  Tem celular  Não tem computador  Tem internet em casa        576.70
#
#     Z_SCORE_NOTA
# 2       0.167597
# 3      -1.690872
# 7      -1.469609
# 9      -1.197007
# 11      0.377274
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Z-SCORE mínimo

# %%
interest_data["Z_SCORE_NOTA"].min()
# Out:
# -6.173141779725277

# %% [markdown]
# ### Z-SCORE máximo

# %%
interest_data["Z_SCORE_NOTA"].max()
# Out:
# 3.5494609291838435

# %% [markdown]
# ## Create a label for grade based on z-score

# %%
NOTA_GERAL_LABELS = [
  "NOTA: MUITO ABAIXO DA MÉDIA",
  "NOTA: ABAIXO DA MÉDIA",
  "NOTA: MÉDIA",
  "NOTA: ACIMA DA MÉDIA",
  "NOTA: MUITO ACIMA DA MÉDIA",
]

interest_data["CLASSIFICACAO_NOTA"] = pd.cut(interest_data["Z_SCORE_NOTA"], bins=[-10, -2, -1, 1, 2, 10], labels=NOTA_GERAL_LABELS)

interest_data.head()
# Out:
#       TP_SEXO TP_ESTADO_CIVIL TP_COR_RACA     TP_FAIXA_ETARIA  \
# 2    Feminino     Solteiro(a)       Preto  Entre 17 e 25 anos
# 3   Masculino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 7    Feminino     Solteiro(a)       Preto  Entre 17 e 25 anos
# 9    Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 11   Feminino     Solteiro(a)      Branco  Entre 17 e 25 anos
#
#                                   TP_ST_CONCLUSAO      TP_ESCOLA  \
# 2                       Já concluí o Ensino Médio  Não Respondeu
# 3                       Já concluí o Ensino Médio  Não Respondeu
# 7                       Já concluí o Ensino Médio  Não Respondeu
# 9                       Já concluí o Ensino Médio  Não Respondeu
# 11  Estou cursando e concluirei o Ensino este ano        Privada
#
#                       TP_DEPENDENCIA_ADM_ESC      SG_UF_PROVA  NU_NOTA_CN  \
# 2   Dependencia administrativa nao informada  Região Nordeste       421.1
# 3   Dependencia administrativa nao informada   Região Sudeste       490.7
# 7   Dependencia administrativa nao informada   Região Sudeste       398.1
# 9   Dependencia administrativa nao informada  Região Nordeste       467.5
# 11  Dependencia administrativa nao informada  Região Nordeste       458.7
#
#     NU_NOTA_CH  ...  NU_NOTA_REDACAO                           Q001  \
# 2        546.0  ...            760.0      Pai Ensino médio completo
# 3        388.6  ...            320.0  Pai Fundamental II incompleto
# 7        427.3  ...            440.0      Pai Ensino médio completo
# 9        461.0  ...            360.0      Pai Ensino médio completo
# 11       539.8  ...            940.0      Pai Ensino médio completo
#
#                          Q002             Q006         Q022  \
# 2      Mãe Graduação completa  Classe Social E  Tem celular
# 3           Mãe nunca estudou  Classe Social E  Tem celular
# 7   Mãe Ensino médio completo  Classe Social E  Tem celular
# 9   Mãe Ensino médio completo  Classe Social E  Tem celular
# 11  Mãe Ensino médio completo  Classe Social E  Tem celular
#
#                   Q024                  Q025 NU_NOTA_GERAL Z_SCORE_NOTA  \
# 2   Não tem computador  Tem internet em casa        558.24     0.167597
# 3       Tem computador  Tem internet em casa        394.62    -1.690872
# 7   Não tem computador  Tem internet em casa        414.10    -1.469609
# 9   Não tem computador  Tem internet em casa        438.10    -1.197007
# 11  Não tem computador  Tem internet em casa        576.70     0.377274
#
#        CLASSIFICACAO_NOTA
# 2             NOTA: MÉDIA
# 3   NOTA: ABAIXO DA MÉDIA
# 7   NOTA: ABAIXO DA MÉDIA
# 9   NOTA: ABAIXO DA MÉDIA
# 11            NOTA: MÉDIA
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Check for uniqueness of all values to check if all of them was translated

# %%
interest_data['TP_SEXO'].unique()
# Out:
# array(['Feminino', 'Masculino'], dtype=object)

# %%
interest_data['TP_ESTADO_CIVIL'].unique()
# Out:
# array(['Solteiro(a)', 'Estado civil: Não informado',
#        'Casado(a) ou mora com companheiro(a)',
#        'Divorciado(a)/Desquitado(a)/Separado(a)', 'Viúvo(a)'],
#       dtype=object)

# %%
interest_data['TP_COR_RACA'].unique()
# Out:
# array(['Preto', 'Pardo', 'Branco', 'Indígena', 'Cor/Raça Não Declarado',
#        'Amarelo'], dtype=object)

# %%
interest_data['TP_FAIXA_ETARIA'].unique()
# Out:
# array(['Entre 17 e 25 anos', 'Menor de 17 anos', 'Entre 26 e 30 anos',
#        'Entre 31 e 35 anos', 'Entre 36 e 40 anos', 'Entre 46 e 50 anos',
#        'Entre 41 e 45 anos', 'Entre 51 e 55 anos', 'Entre 56 e 60 anos',
#        'Entre 61 e 65 anos', 'Maior de 70 anos', 'Entre 66 e 70 anos'],
#       dtype=object)

# %%
interest_data['TP_ST_CONCLUSAO'].unique()
# Out:
# array(['Já concluí o Ensino Médio',
#        'Estou cursando e concluirei o Ensino este ano',
#        'Estou cursando e concluirei o Ensino Médio após este ano',
#        'Não concluí e não estou cursando o Ensino Médio'], dtype=object)

# %%
interest_data['TP_ESCOLA'].unique()
# Out:
# array(['Não Respondeu', 'Privada', 'Pública'], dtype=object)

# %%
interest_data['TP_DEPENDENCIA_ADM_ESC'].unique()
# Out:
# array(['Dependencia administrativa nao informada', 'Estadual', 'Privada',
#        'Municipal', 'Federal'], dtype=object)

# %%
interest_data['SG_UF_PROVA'].unique()
# Out:
# array(['Região Nordeste', 'Região Sudeste', 'Região Norte', 'Região Sul',
#        'Região Centro-Oeste'], dtype=object)

# %%
interest_data['Q001'].unique()
# Out:
# array(['Pai Ensino médio completo', 'Pai Fundamental II incompleto',
#        'Pai Pós-graduação completa', 'Pai Fundamental I incompleto',
#        'Não sei a escolaridade do meu pai', 'Pai nunca estudou',
#        'Pai Ensino médio incompleto', 'Pai Graduação completa'],
#       dtype=object)

# %%
interest_data['Q002'].unique()
# Out:
# array(['Mãe Graduação completa', 'Mãe nunca estudou',
#        'Mãe Ensino médio completo', 'Mãe Ensino médio incompleto',
#        'Mãe Fundamental II incompleto',
#        'Não sei a escolaridade da minha mãe',
#        'Mãe Fundamental I incompleto', 'Mãe Pós-graduação completa'],
#       dtype=object)

# %%
interest_data['Q006'].unique()
# Out:
# array(['Classe Social E', 'Classe Social D', 'Classe Social C',
#        'Classe Social A', 'Classe Social B'], dtype=object)

# %%
interest_data['Q022'].unique()
# Out:
# array(['Tem celular', 'Não tem celular'], dtype=object)

# %%
interest_data['Q024'].unique()
# Out:
# array(['Não tem computador', 'Tem computador'], dtype=object)

# %%
interest_data['Q025'].unique()
# Out:
# array(['Tem internet em casa', 'Não tem internet em casa'], dtype=object)

# %%
interest_data['CLASSIFICACAO_NOTA'].unique()
# Out:
# ['NOTA: MÉDIA', 'NOTA: ABAIXO DA MÉDIA', 'NOTA: ACIMA DA MÉDIA', 'NOTA: MUITO ABAIXO DA MÉDIA', 'NOTA: MUITO ACIMA DA MÉDIA']
# Categories (5, object): ['NOTA: MUITO ABAIXO DA MÉDIA' < 'NOTA: ABAIXO DA MÉDIA' < 'NOTA: MÉDIA' < 'NOTA: ACIMA DA MÉDIA' < 'NOTA: MUITO ACIMA DA MÉDIA']

# %% [markdown]
# ## Generate histograms by grade z-score

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

data = interest_data['Z_SCORE_NOTA'].to_numpy()

mu, std = norm.fit(data) 
  
# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k', linewidth=2)
  
plt.show()

# %% [markdown]
# ## Filter by grades far above or far below average

# %%
filtered_interest_data = interest_data.query("Z_SCORE_NOTA > 2.00 or Z_SCORE_NOTA < -2.00")
filtered_interest_data.count()
# Out:
# TP_SEXO                   125412
# TP_ESTADO_CIVIL           125412
# TP_COR_RACA               125412
# TP_FAIXA_ETARIA           125412
# TP_ST_CONCLUSAO           125412
# TP_ESCOLA                 125412
# TP_DEPENDENCIA_ADM_ESC    125412
# SG_UF_PROVA               125412
# NU_NOTA_CN                125412
# NU_NOTA_CH                125412
# NU_NOTA_LC                125412
# NU_NOTA_MT                125412
# NU_NOTA_REDACAO           125412
# Q001                      125412
# Q002                      125412
# Q006                      125412
# Q022                      125412
# Q024                      125412
# Q025                      125412
# NU_NOTA_GERAL             125412
# Z_SCORE_NOTA              125412
# CLASSIFICACAO_NOTA        125412
# dtype: int64

# %%
analysis_interest_columns = [
    'TP_SEXO',
    'TP_ESTADO_CIVIL',
    'TP_COR_RACA',
    'TP_FAIXA_ETARIA',
    'TP_ST_CONCLUSAO',
    'TP_ESCOLA',
    'TP_DEPENDENCIA_ADM_ESC',
    'SG_UF_PROVA',
    'CLASSIFICACAO_NOTA',
    'Q001',
    'Q002',
    'Q006',
    'Q022',
    'Q024',
    'Q025'
]

analysis_interest_data = filtered_interest_data[analysis_interest_columns]

# %% [markdown]
# ## Save a CSV file with the analysis interest data

# %%
import os  

os.makedirs('analysis_interest_data', exist_ok=True)  
analysis_interest_data.to_csv('analysis_interest_data/analysis-interest-data-2022.csv')

analysis_file_data = pd.read_csv('analysis_interest_data/analysis-interest-data-2022.csv', sep=',', encoding='UTF-8')
analysis_file_data.head()
# Out:
#    Unnamed: 0    TP_SEXO TP_ESTADO_CIVIL TP_COR_RACA     TP_FAIXA_ETARIA  \
# 0          49   Feminino     Solteiro(a)       Preto  Entre 17 e 25 anos
# 1          55   Feminino     Solteiro(a)      Branco  Entre 17 e 25 anos
# 2          94  Masculino     Solteiro(a)       Pardo  Entre 26 e 30 anos
# 3         135   Feminino     Solteiro(a)      Branco  Entre 17 e 25 anos
# 4         136   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
#
#                                  TP_ST_CONCLUSAO      TP_ESCOLA  \
# 0  Estou cursando e concluirei o Ensino este ano        Pública
# 1  Estou cursando e concluirei o Ensino este ano        Pública
# 2                      Já concluí o Ensino Médio  Não Respondeu
# 3                      Já concluí o Ensino Médio  Não Respondeu
# 4  Estou cursando e concluirei o Ensino este ano        Pública
#
#                      TP_DEPENDENCIA_ADM_ESC      SG_UF_PROVA  \
# 0  Dependencia administrativa nao informada  Região Nordeste
# 1                                   Privada   Região Sudeste
# 2  Dependencia administrativa nao informada  Região Nordeste
# 3  Dependencia administrativa nao informada   Região Sudeste
# 4  Dependencia administrativa nao informada  Região Nordeste
#
#             CLASSIFICACAO_NOTA                           Q001  \
# 0  NOTA: MUITO ABAIXO DA MÉDIA              Pai nunca estudou
# 1   NOTA: MUITO ACIMA DA MÉDIA    Pai Ensino médio incompleto
# 2  NOTA: MUITO ABAIXO DA MÉDIA   Pai Fundamental I incompleto
# 3  NOTA: MUITO ABAIXO DA MÉDIA      Pai Ensino médio completo
# 4  NOTA: MUITO ABAIXO DA MÉDIA  Pai Fundamental II incompleto
#
#                            Q002             Q006         Q022  \
# 0   Mãe Ensino médio incompleto  Classe Social E  Tem celular
# 1        Mãe Graduação completa  Classe Social E  Tem celular
# 2  Mãe Fundamental I incompleto  Classe Social E  Tem celular
# 3   Mãe Ensino médio incompleto  Classe Social E  Tem celular
# 4     Mãe Ensino médio completo  Classe Social E  Tem celular
#
#                  Q024                  Q025
# 0  Não tem computador  Tem internet em casa
# 1      Tem computador  Tem internet em casa
# 2  Não tem computador  Tem internet em casa
# 3  Não tem computador  Tem internet em casa
# 4  Não tem computador  Tem internet em casa

# %% [markdown]
# ## Convert table to transactions

# %%
transactions = analysis_interest_data.to_numpy()
transactions
# Out:
# array([['Feminino', 'Solteiro(a)', 'Preto', ..., 'Tem celular',
#         'Não tem computador', 'Tem internet em casa'],
#        ['Feminino', 'Solteiro(a)', 'Branco', ..., 'Tem celular',
#         'Tem computador', 'Tem internet em casa'],
#        ['Masculino', 'Solteiro(a)', 'Pardo', ..., 'Tem celular',
#         'Não tem computador', 'Tem internet em casa'],
#        ...,
#        ['Masculino', 'Solteiro(a)', 'Branco', ..., 'Tem celular',
#         'Não tem computador', 'Tem internet em casa'],
#        ['Masculino', 'Solteiro(a)', 'Pardo', ..., 'Tem celular',
#         'Tem computador', 'Tem internet em casa'],
#        ['Masculino', 'Solteiro(a)', 'Preto', ..., 'Não tem celular',
#         'Não tem computador', 'Tem internet em casa']], dtype=object)

# %% [markdown]
# ## Create apriori rules

# %%
# %run '../scripts/apriori-params-setup.py'
rules = apriori(transactions, min_support=support, min_confidence=confidence)
rules
# Out:
# <generator object apriori at 0x1701d92e0>

# %% [markdown]
# ## Run apriori

# %%
from datetime import datetime

initial_time = datetime.now()

results = pd.DataFrame(list(rules))

execution_time = datetime.now() - initial_time
print("Time to run apriori: " + str(execution_time))
# Out:
# Time to run apriori: 0:15:27.821784

# %%
results
# Out:
#                                                   items   support  \
# 0                                     (Classe Social E)  0.571421
# 1            (Dependencia administrativa nao informada)  0.680995
# 2                                  (Entre 17 e 25 anos)  0.845940
# 3                                            (Feminino)  0.565831
# 4                         (NOTA: MUITO ABAIXO DA MÉDIA)  0.513101
# ...                                                 ...       ...
# 1900  (Não Respondeu, Entre 17 e 25 anos, NOTA: MUIT...  0.274360
# 1901  (Não Respondeu, NOTA: MUITO ACIMA DA MÉDIA, De...  0.283761
# 1902  (Não Respondeu, Entre 17 e 25 anos, NOTA: MUIT...  0.262830
# 1903  (Não Respondeu, Branco, NOTA: MUITO ACIMA DA M...  0.200395
# 1904  (Não Respondeu, Entre 17 e 25 anos, NOTA: MUIT...  0.262830
#
#                                      ordered_statistics
# 0     [((), (Classe Social E), 0.571420597709948, 1.0)]
# 1     [((), (Dependencia administrativa nao informad...
# 2     [((), (Entre 17 e 25 anos), 0.845939782476956,...
# 3           [((), (Feminino), 0.5658310209549325, 1.0)]
# 4     [((), (NOTA: MUITO ABAIXO DA MÉDIA), 0.5131008...
# ...                                                 ...
# 1900  [((NOTA: MUITO ACIMA DA MÉDIA), (Não Respondeu...
# 1901  [((Já concluí o Ensino Médio), (Não Respondeu,...
# 1902  [((Já concluí o Ensino Médio), (Não Respondeu,...
# 1903  [((Dependencia administrativa nao informada, B...
# 1904  [((Já concluí o Ensino Médio), (Não Respondeu,...
#
# [1905 rows x 3 columns]

# %% [markdown]
# ## Extract results to a new table

# %%
# %run '../scripts/extractor.py'

organized_rules = extractor(results)
organized_rules
# Out:
#                                               items_base  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 42510  [Entre 17 e 25 anos, NOTA: MUITO ACIMA DA MÉDI...
# 42511  [Não Respondeu, Entre 17 e 25 anos, Dependenci...
# 42512  [Não Respondeu, Entre 17 e 25 anos, NOTA: MUIT...
# 42513  [Não Respondeu, NOTA: MUITO ACIMA DA MÉDIA, De...
# 42514  [Não Respondeu, Entre 17 e 25 anos, NOTA: MUIT...
#
#                                         items_add   support confidence  \
# 0                               [Classe Social E]  0.571421   0.571421
# 1      [Dependencia administrativa nao informada]  0.680995   0.680995
# 2                            [Entre 17 e 25 anos]   0.84594    0.84594
# 3                                      [Feminino]  0.565831   0.565831
# 4                   [NOTA: MUITO ABAIXO DA MÉDIA]  0.513101   0.513101
# ...                                           ...       ...        ...
# 42510                             [Não Respondeu]   0.26283        1.0
# 42511                [NOTA: MUITO ACIMA DA MÉDIA]   0.26283   0.914443
# 42512                 [Já concluí o Ensino Médio]   0.26283   0.957975
# 42513                        [Entre 17 e 25 anos]   0.26283   0.926237
# 42514  [Dependencia administrativa nao informada]   0.26283        1.0
#
#            lift
# 0           1.0
# 1           1.0
# 2           1.0
# 3           1.0
# 4           1.0
# ...         ...
# 42510  1.690941
# 42511  1.878094
# 42512  2.036746
# 42513  1.094921
# 42514  1.468439
#
# [42515 rows x 5 columns]

# %%
rules_count = len(organized_rules.index)
print("Count of association rules for support " + str((support *100)) + "% and confidence " + str((confidence * 100)) + "%: " + str(rules_count))
# Out:
# Count of association rules for support 20.0% and confidence 50.0%: 42515

# %% [markdown]
# ## Save results to a new CSV file

# %%
import os  

os.makedirs('results', exist_ok=True)  
organized_rules.to_csv('results/organized-associations-2022.csv')
