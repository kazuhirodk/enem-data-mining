# %% [markdown]
# # Analysis from ENADE microdata for 2017

# %% [markdown]
# ## Import libs

# %%
import pandas as pd
from apyori import apriori

# %% [markdown]
# ## Read microdata file

# %%
data = pd.read_csv('../microdata/microdata-enade-2017.csv', sep=';', encoding='ISO-8859-1', low_memory=False)
data
# Out:
#         nu_ano_enade  co_ies                               no_ies sg_ies  \
# 0               2017     322                UNIVERSIDADE PAULISTA   UNIP
# 1               2017     322                UNIVERSIDADE PAULISTA   UNIP
# 2               2017     322                UNIVERSIDADE PAULISTA   UNIP
# 3               2017     322                UNIVERSIDADE PAULISTA   UNIP
# 4               2017     322                UNIVERSIDADE PAULISTA   UNIP
# ...              ...     ...                                  ...    ...
# 537431          2017     514  CENTRO UNIVERSITÁRIO DE BARRA MANSA    UBM
# 537432          2017     514  CENTRO UNIVERSITÁRIO DE BARRA MANSA    UBM
# 537433          2017     514  CENTRO UNIVERSITÁRIO DE BARRA MANSA    UBM
# 537434          2017     514  CENTRO UNIVERSITÁRIO DE BARRA MANSA    UBM
# 537435          2017     514  CENTRO UNIVERSITÁRIO DE BARRA MANSA    UBM
#
#         co_mantenedora_ies                                 no_mantenedora_ies  \
# 0                   2415.0  ASSOCIACAO UNIFICADA PAULISTA DE ENSINO RENOVA...
# 1                   2415.0  ASSOCIACAO UNIFICADA PAULISTA DE ENSINO RENOVA...
# 2                   2415.0  ASSOCIACAO UNIFICADA PAULISTA DE ENSINO RENOVA...
# 3                   2415.0  ASSOCIACAO UNIFICADA PAULISTA DE ENSINO RENOVA...
# 4                   2415.0  ASSOCIACAO UNIFICADA PAULISTA DE ENSINO RENOVA...
# ...                    ...                                                ...
# 537431               355.0         SOBEU - ASSOCIACAO BARRAMANSENSE DE ENSINO
# 537432               355.0         SOBEU - ASSOCIACAO BARRAMANSENSE DE ENSINO
# 537433               355.0         SOBEU - ASSOCIACAO BARRAMANSENSE DE ENSINO
# 537434               355.0         SOBEU - ASSOCIACAO BARRAMANSENSE DE ENSINO
# 537435               355.0         SOBEU - ASSOCIACAO BARRAMANSENSE DE ENSINO
#
#         tp_categoria_administrativa_ies no_categoria_administrativa_ies  \
# 0                                   5.0     Privada sem fins lucrativos
# 1                                   5.0     Privada sem fins lucrativos
# 2                                   5.0     Privada sem fins lucrativos
# 3                                   5.0     Privada sem fins lucrativos
# 4                                   5.0     Privada sem fins lucrativos
# ...                                 ...                             ...
# 537431                              5.0     Privada sem fins lucrativos
# 537432                              5.0     Privada sem fins lucrativos
# 537433                              5.0     Privada sem fins lucrativos
# 537434                              5.0     Privada sem fins lucrativos
# 537435                              5.0     Privada sem fins lucrativos
#
#         tp_organizacao_academica_ies no_organizacao_academica_ies  ...  q72  \
# 0                                1.0                 Universidade  ...    *
# 1                                1.0                 Universidade  ...    *
# 2                                1.0                 Universidade  ...    *
# 3                                1.0                 Universidade  ...    *
# 4                                1.0                 Universidade  ...    *
# ...                              ...                          ...  ...  ...
# 537431                           2.0         Centro Universitário  ...    *
# 537432                           2.0         Centro Universitário  ...    *
# 537433                           2.0         Centro Universitário  ...    *
# 537434                           2.0         Centro Universitário  ...    *
# 537435                           2.0         Centro Universitário  ...    *
#
#        q73  q74 q75 q76  q77 q78  q79  q80 q81
# 0        *    *   *   *    *   *    *    *   *
# 1        *    *   *   *    *   *    *    *   *
# 2        *    *   *   *    *   *    *    *   *
# 3        *    *   *   *    *   *    *    *   *
# 4        *    *   *   *    *   *    *    *   *
# ...     ..  ...  ..  ..  ...  ..  ...  ...  ..
# 537431   *    *   *   *    *   *    *    *   *
# 537432   *    *   *   *    *   *    *    *   *
# 537433   *    *   *   *    *   *    *    *   *
# 537434   *    *   *   *    *   *    *    *   *
# 537435   *    *   *   *    *   *    *    *   *
#
# [537436 rows x 148 columns]

# %% [markdown]
# ## Select only columns of interest

# %%
interest_columns = [
    'no_categoria_administrativa_ies',
    'no_organizacao_academica_ies',
    'no_regiao_ies',
    'no_grau_academico',
    'no_modalidade',
    'faixa_etaria',
    'tp_sexo',
    'no_pres',
    'nt_ger',
    'q1', # Estado civil
    'q2', # Cor ou raça
    'q4', # Escolaridade do pai
    'q5', # Escolaridade da mãe
    'q8', # Renda total da família
    'q9', # Situação financeira
    'q10', # Situação de trabalho
    'q15', # Entrou por alguma política afirmativa?
    'q17', # Em que tipo de escola cursou o EM?
    'q21', # Alguém da família concluiu ensino superior?
    'q58', # Docentes utilizaram TICs como estratégia de ensino?
]

interest_data = data[interest_columns]

interest_data.head()
# Out:
#   no_categoria_administrativa_ies no_organizacao_academica_ies no_regiao_ies  \
# 0     Privada sem fins lucrativos                 Universidade       Sudeste
# 1     Privada sem fins lucrativos                 Universidade       Sudeste
# 2     Privada sem fins lucrativos                 Universidade       Sudeste
# 3     Privada sem fins lucrativos                 Universidade       Sudeste
# 4     Privada sem fins lucrativos                 Universidade       Sudeste
#
#   no_grau_academico no_modalidade  faixa_etaria tp_sexo no_pres nt_ger q1 q2  \
# 0      Licenciatura           EaD            10       M     NaN    NaN  *  *
# 1       Tecnológico           EaD             4       M     NaN    NaN  *  *
# 2       Tecnológico           EaD             4       M     NaN    NaN  *  *
# 3       Tecnológico           EaD             5       M     NaN    NaN  *  *
# 4      Licenciatura           EaD             8       F     NaN    NaN  *  *
#
#   q4 q5 q8 q9 q10 q15 q17 q21 q58
# 0  *  *  *  *   *   *   *   *   *
# 1  *  *  *  *   *   *   *   *   *
# 2  *  *  *  *   *   *   *   *   *
# 3  *  *  *  *   *   *   *   *   *
# 4  *  *  *  *   *   *   *   *   *

# %% [markdown]
# ### Check count for valid values

# %%
interest_data.count()
# Out:
# no_categoria_administrativa_ies    537327
# no_organizacao_academica_ies       537327
# no_regiao_ies                      537327
# no_grau_academico                  535243
# no_modalidade                      537436
# faixa_etaria                       537436
# tp_sexo                            537436
# no_pres                            537425
# nt_ger                             449932
# q1                                 537436
# q2                                 537436
# q4                                 537436
# q5                                 537436
# q8                                 537436
# q9                                 537436
# q10                                537436
# q15                                537436
# q17                                537436
# q21                                537436
# q58                                537436
# dtype: int64

# %% [markdown]
# ## Translate some columns to better readability

# %%
# %run '../scripts/attribute-dictionary.py'

interest_data = interest_data.replace(dictionary_params)

interest_data['nt_ger'] = interest_data['nt_ger'].str.replace(',', '.')
interest_data["NOTA_GERAL"] = pd.to_numeric(interest_data["nt_ger"], errors='coerce')

interest_data.head()
# Out:
#   no_categoria_administrativa_ies no_organizacao_academica_ies no_regiao_ies  \
# 0     Privada sem fins lucrativos                 Universidade       Sudeste
# 1     Privada sem fins lucrativos                 Universidade       Sudeste
# 2     Privada sem fins lucrativos                 Universidade       Sudeste
# 3     Privada sem fins lucrativos                 Universidade       Sudeste
# 4     Privada sem fins lucrativos                 Universidade       Sudeste
#
#   no_grau_academico no_modalidade        faixa_etaria    tp_sexo no_pres  \
# 0      Licenciatura           EaD  Entre 50 e 57 anos  Masculino     NaN
# 1       Tecnológico           EaD  Entre 26 e 33 anos  Masculino     NaN
# 2       Tecnológico           EaD  Entre 26 e 33 anos  Masculino     NaN
# 3       Tecnológico           EaD  Entre 26 e 33 anos  Masculino     NaN
# 4      Licenciatura           EaD  Entre 42 e 49 anos   Feminino     NaN
#
#   nt_ger q1  ... q4 q5 q8 q9 q10 q15 q17 q21 q58 NOTA_GERAL
# 0    NaN  *  ...  *  *  *  *   *   *   *   *   *        NaN
# 1    NaN  *  ...  *  *  *  *   *   *   *   *   *        NaN
# 2    NaN  *  ...  *  *  *  *   *   *   *   *   *        NaN
# 3    NaN  *  ...  *  *  *  *   *   *   *   *   *        NaN
# 4    NaN  *  ...  *  *  *  *   *   *   *   *   *        NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Remove nil values and filter by relevant data

# %%
interest_data = interest_data.query("no_categoria_administrativa_ies.notnull() and no_organizacao_academica_ies.notnull() and no_regiao_ies.notnull() and no_grau_academico.notnull() and no_modalidade.notnull() and faixa_etaria.notnull() and tp_sexo.notnull() and no_pres.notnull() and nt_ger.notnull() and q1.notnull() and q2.notnull() and q4.notnull() and q5.notnull() and q8.notnull() and q9.notnull() and q10.notnull() and q15.notnull() and q17.notnull() and q21.notnull() and q58.notnull() and no_pres == 'Presente com resultado válido'")
interest_data = interest_data.query("no_categoria_administrativa_ies != '*' and no_organizacao_academica_ies != '*' and no_regiao_ies != '*' and no_grau_academico != '*' and no_modalidade != '*' and faixa_etaria != '*' and tp_sexo != '*' and no_pres != '*' and nt_ger != '*' and q1 != '*' and q2 != '*' and q4 != '*' and q5 != '*' and q8 != '*' and q9 != '*' and q10 != '*' and q15 != '*' and q17 != '*' and q21 != '*' and q58 != '*'")

interest_data.head()
# Out:
#       no_categoria_administrativa_ies no_organizacao_academica_ies  \
# 86384                 Pública Federal                 Universidade
# 86385                 Pública Federal                 Universidade
# 86386                 Pública Federal                 Universidade
# 86387                 Pública Federal                 Universidade
# 86388                 Pública Federal                 Universidade
#
#       no_regiao_ies no_grau_academico no_modalidade        faixa_etaria  \
# 86384         Norte      Licenciatura           EaD  Entre 34 e 41 anos
# 86385         Norte      Licenciatura           EaD  Entre 42 e 49 anos
# 86386         Norte      Licenciatura           EaD  Entre 34 e 41 anos
# 86387         Norte      Licenciatura           EaD  Entre 34 e 41 anos
# 86388         Norte      Licenciatura           EaD  Entre 34 e 41 anos
#
#         tp_sexo                        no_pres nt_ger           q1  ...  \
# 86384  Feminino  Presente com resultado válido     18  Solteiro(a)  ...
# 86385  Feminino  Presente com resultado válido   24.5  Solteiro(a)  ...
# 86386  Feminino  Presente com resultado válido   22.1  Solteiro(a)  ...
# 86387  Feminino  Presente com resultado válido   48.4  Separado(a)  ...
# 86388  Feminino  Presente com resultado válido   51.3    Casado(a)  ...
#
#                               q4                         q5               q8  \
# 86384  Pai: Ensino Fundamental I  Mãe: Ensino Fundamental I  Classe Social E
# 86385  Pai: Nenhuma escolaridade  Mãe: Nenhuma escolaridade  Classe Social E
# 86386  Pai: Nenhuma escolaridade  Mãe: Ensino Fundamental I  Classe Social E
# 86387  Pai: Ensino Fundamental I  Mãe: Ensino Fundamental I  Classe Social E
# 86388  Pai: Ensino Fundamental I  Mãe: Nenhuma escolaridade  Classe Social E
#
#                                                       q9  \
# 86384     Sem renda, financiado por familiares ou outros
# 86385  Sou o principal responsável pelo sustento da f...
# 86386     Sem renda, financiado por familiares ou outros
# 86387  Sou o principal responsável pelo sustento da f...
# 86388  Tenho renda e contribuo com o sustento da família
#
#                                       q10                   q15  \
# 86384               Não estou trabalhando  Não entrei por cotas
# 86385  Trabalho 40 horas semanais ou mais  Não entrei por cotas
# 86386              Trabalho eventualmente  Não entrei por cotas
# 86387  Trabalho 40 horas semanais ou mais  Não entrei por cotas
# 86388  Trabalho 40 horas semanais ou mais  Não entrei por cotas
#
#                               q17                               q21  \
# 86384  EM: Todo em escola pública      Tenho familiar com graduação
# 86385  EM: Todo em escola pública  Não tenho familiar com graduação
# 86386  EM: Todo em escola pública      Tenho familiar com graduação
# 86387  EM: Todo em escola pública      Tenho familiar com graduação
# 86388  EM: Todo em escola pública  Não tenho familiar com graduação
#
#                                        q58 NOTA_GERAL
# 86384    IE Usou TICs: Concordo totalmente       18.0
# 86385    IE Usou TICs: Concordo totalmente       24.5
# 86386  IE Usou TICs: Discordo parcialmente       22.1
# 86387               IE Usou TICs: Concordo       48.4
# 86388    IE Usou TICs: Concordo totalmente       51.3
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Check count for valid values

# %%
interest_data.count()
# Out:
# no_categoria_administrativa_ies    441148
# no_organizacao_academica_ies       441148
# no_regiao_ies                      441148
# no_grau_academico                  441148
# no_modalidade                      441148
# faixa_etaria                       441148
# tp_sexo                            441148
# no_pres                            441148
# nt_ger                             441148
# q1                                 441148
# q2                                 441148
# q4                                 441148
# q5                                 441148
# q8                                 441148
# q9                                 441148
# q10                                441148
# q15                                441148
# q17                                441148
# q21                                441148
# q58                                441148
# NOTA_GERAL                         441148
# dtype: int64

# %% [markdown]
# ## Calculate Z-SCORE from NU_NOTA_GERAL

# %%
from scipy.stats import zscore

interest_data["Z_SCORE_NOTA"] = zscore(interest_data["NOTA_GERAL"])
interest_data.head()
# Out:
#       no_categoria_administrativa_ies no_organizacao_academica_ies  \
# 86384                 Pública Federal                 Universidade
# 86385                 Pública Federal                 Universidade
# 86386                 Pública Federal                 Universidade
# 86387                 Pública Federal                 Universidade
# 86388                 Pública Federal                 Universidade
#
#       no_regiao_ies no_grau_academico no_modalidade        faixa_etaria  \
# 86384         Norte      Licenciatura           EaD  Entre 34 e 41 anos
# 86385         Norte      Licenciatura           EaD  Entre 42 e 49 anos
# 86386         Norte      Licenciatura           EaD  Entre 34 e 41 anos
# 86387         Norte      Licenciatura           EaD  Entre 34 e 41 anos
# 86388         Norte      Licenciatura           EaD  Entre 34 e 41 anos
#
#         tp_sexo                        no_pres nt_ger           q1  ...  \
# 86384  Feminino  Presente com resultado válido     18  Solteiro(a)  ...
# 86385  Feminino  Presente com resultado válido   24.5  Solteiro(a)  ...
# 86386  Feminino  Presente com resultado válido   22.1  Solteiro(a)  ...
# 86387  Feminino  Presente com resultado válido   48.4  Separado(a)  ...
# 86388  Feminino  Presente com resultado válido   51.3    Casado(a)  ...
#
#                               q5               q8  \
# 86384  Mãe: Ensino Fundamental I  Classe Social E
# 86385  Mãe: Nenhuma escolaridade  Classe Social E
# 86386  Mãe: Ensino Fundamental I  Classe Social E
# 86387  Mãe: Ensino Fundamental I  Classe Social E
# 86388  Mãe: Nenhuma escolaridade  Classe Social E
#
#                                                       q9  \
# 86384     Sem renda, financiado por familiares ou outros
# 86385  Sou o principal responsável pelo sustento da f...
# 86386     Sem renda, financiado por familiares ou outros
# 86387  Sou o principal responsável pelo sustento da f...
# 86388  Tenho renda e contribuo com o sustento da família
#
#                                       q10                   q15  \
# 86384               Não estou trabalhando  Não entrei por cotas
# 86385  Trabalho 40 horas semanais ou mais  Não entrei por cotas
# 86386              Trabalho eventualmente  Não entrei por cotas
# 86387  Trabalho 40 horas semanais ou mais  Não entrei por cotas
# 86388  Trabalho 40 horas semanais ou mais  Não entrei por cotas
#
#                               q17                               q21  \
# 86384  EM: Todo em escola pública      Tenho familiar com graduação
# 86385  EM: Todo em escola pública  Não tenho familiar com graduação
# 86386  EM: Todo em escola pública      Tenho familiar com graduação
# 86387  EM: Todo em escola pública      Tenho familiar com graduação
# 86388  EM: Todo em escola pública  Não tenho familiar com graduação
#
#                                        q58 NOTA_GERAL Z_SCORE_NOTA
# 86384    IE Usou TICs: Concordo totalmente       18.0    -1.823262
# 86385    IE Usou TICs: Concordo totalmente       24.5    -1.360998
# 86386  IE Usou TICs: Discordo parcialmente       22.1    -1.531680
# 86387               IE Usou TICs: Concordo       48.4     0.338711
# 86388    IE Usou TICs: Concordo totalmente       51.3     0.544952
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Z-SCORE mínimo

# %%
interest_data["Z_SCORE_NOTA"].min()
# Out:
# -3.1033779849903675

# %% [markdown]
# ### Z-SCORE máximo

# %%
interest_data["Z_SCORE_NOTA"].max()
# Out:
# 3.873252172193255

# %% [markdown]
# ## Create a label for grade based on z-score

# %%
NOTA_GERAL_LABELS = [
  "NOTA: MUITO ABAIXO DA MÉDIA",
  "NOTA: ABAIXO DA MÉDIA",
  "NOTA: MÉDIA",
  "NOTA: ACIMA DA MÉDIA",
  "NOTA: MUITO ACIMA DA MÉDIA",
]

interest_data["CLASSIFICACAO_NOTA"] = pd.cut(interest_data["Z_SCORE_NOTA"], bins=[-10, -2, -1, 1, 2, 10], labels=NOTA_GERAL_LABELS)

interest_data.head()
# Out:
#       no_categoria_administrativa_ies no_organizacao_academica_ies  \
# 86384                 Pública Federal                 Universidade
# 86385                 Pública Federal                 Universidade
# 86386                 Pública Federal                 Universidade
# 86387                 Pública Federal                 Universidade
# 86388                 Pública Federal                 Universidade
#
#       no_regiao_ies no_grau_academico no_modalidade        faixa_etaria  \
# 86384         Norte      Licenciatura           EaD  Entre 34 e 41 anos
# 86385         Norte      Licenciatura           EaD  Entre 42 e 49 anos
# 86386         Norte      Licenciatura           EaD  Entre 34 e 41 anos
# 86387         Norte      Licenciatura           EaD  Entre 34 e 41 anos
# 86388         Norte      Licenciatura           EaD  Entre 34 e 41 anos
#
#         tp_sexo                        no_pres nt_ger           q1  ...  \
# 86384  Feminino  Presente com resultado válido     18  Solteiro(a)  ...
# 86385  Feminino  Presente com resultado válido   24.5  Solteiro(a)  ...
# 86386  Feminino  Presente com resultado válido   22.1  Solteiro(a)  ...
# 86387  Feminino  Presente com resultado válido   48.4  Separado(a)  ...
# 86388  Feminino  Presente com resultado válido   51.3    Casado(a)  ...
#
#                     q8                                                 q9  \
# 86384  Classe Social E     Sem renda, financiado por familiares ou outros
# 86385  Classe Social E  Sou o principal responsável pelo sustento da f...
# 86386  Classe Social E     Sem renda, financiado por familiares ou outros
# 86387  Classe Social E  Sou o principal responsável pelo sustento da f...
# 86388  Classe Social E  Tenho renda e contribuo com o sustento da família
#
#                                       q10                   q15  \
# 86384               Não estou trabalhando  Não entrei por cotas
# 86385  Trabalho 40 horas semanais ou mais  Não entrei por cotas
# 86386              Trabalho eventualmente  Não entrei por cotas
# 86387  Trabalho 40 horas semanais ou mais  Não entrei por cotas
# 86388  Trabalho 40 horas semanais ou mais  Não entrei por cotas
#
#                               q17                               q21  \
# 86384  EM: Todo em escola pública      Tenho familiar com graduação
# 86385  EM: Todo em escola pública  Não tenho familiar com graduação
# 86386  EM: Todo em escola pública      Tenho familiar com graduação
# 86387  EM: Todo em escola pública      Tenho familiar com graduação
# 86388  EM: Todo em escola pública  Não tenho familiar com graduação
#
#                                        q58 NOTA_GERAL Z_SCORE_NOTA  \
# 86384    IE Usou TICs: Concordo totalmente       18.0    -1.823262
# 86385    IE Usou TICs: Concordo totalmente       24.5    -1.360998
# 86386  IE Usou TICs: Discordo parcialmente       22.1    -1.531680
# 86387               IE Usou TICs: Concordo       48.4     0.338711
# 86388    IE Usou TICs: Concordo totalmente       51.3     0.544952
#
#           CLASSIFICACAO_NOTA
# 86384  NOTA: ABAIXO DA MÉDIA
# 86385  NOTA: ABAIXO DA MÉDIA
# 86386  NOTA: ABAIXO DA MÉDIA
# 86387            NOTA: MÉDIA
# 86388            NOTA: MÉDIA
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Check for uniqueness of all values to check if all of them was translated

# %%
interest_data['no_categoria_administrativa_ies'].unique()
# Out:
# array(['Pública Federal', 'Privada com fins lucrativos',
#        'Pública Estadual', 'Privada sem fins lucrativos',
#        'Pública Municipal', 'Especial'], dtype=object)

# %%
interest_data['no_organizacao_academica_ies'].unique()
# Out:
# array(['Universidade',
#        'Instituto Federal de Educação, Ciência e Tecnologia', 'Faculdade',
#        'Centro Universitário', 'Centro Federal de Educação Tecnológica'],
#       dtype=object)

# %%
interest_data['no_regiao_ies'].unique()
# Out:
# array(['Norte', 'Sul', 'Nordeste', 'Sudeste', 'Centro_Oeste'],
#       dtype=object)

# %%
interest_data['no_grau_academico'].unique()
# Out:
# array(['Licenciatura', 'Bacharelado', 'Tecnológico'], dtype=object)

# %%
interest_data['no_modalidade'].unique()
# Out:
# array(['EaD', 'Presencial'], dtype=object)

# %%
interest_data['faixa_etaria'].unique()
# Out:
# array(['Entre 34 e 41 anos', 'Entre 42 e 49 anos', 'Entre 58 e 65 anos',
#        'Entre 50 e 57 anos', 'Entre 26 e 33 anos', 'Entre 17 e 25 anos',
#        'Acima de 65 anos', 'Até 17 anos'], dtype=object)

# %%
interest_data['tp_sexo'].unique()
# Out:
# array(['Feminino', 'Masculino'], dtype=object)

# %%
interest_data['no_pres'].unique()
# Out:
# array(['Presente com resultado válido'], dtype=object)

# %%
interest_data['q1'].unique()
# Out:
# array(['Solteiro(a)', 'Separado(a)', 'Casado(a)', 'Estado Civil: Outro',
#        'Viúvo(a)'], dtype=object)

# %%
interest_data['q2'].unique()
# Out:
# array(['Parda', 'Branca', 'Amarela', 'Preta', 'Raça/Cor não declarada',
#        'Indígena'], dtype=object)

# %%
interest_data['q4'].unique()
# Out:
# array(['Pai: Ensino Fundamental I', 'Pai: Nenhuma escolaridade',
#        'Pai: Ensino Fundamental II', 'Pai: Ensino Superior - Graduação',
#        'Pai: Ensino Médio', 'Pai: Pós-graduação'], dtype=object)

# %%
interest_data['q5'].unique()
# Out:
# array(['Mãe: Ensino Fundamental I', 'Mãe: Nenhuma escolaridade',
#        'Mãe: Ensino Fundamental II', 'Mãe: Ensino Médio',
#        'Mãe: Pós-graduação', 'Mãe: Ensino Superior - Graduação'],
#       dtype=object)

# %%
interest_data['q8'].unique()
# Out:
# array(['Classe Social E', 'Classe Social D', 'Classe Social C',
#        'Classe Social B', 'Classe Social A'], dtype=object)

# %%
interest_data['q9'].unique()
# Out:
# array(['Sem renda, financiado por familiares ou outros',
#        'Sou o principal responsável pelo sustento da família',
#        'Tenho renda e contribuo com o sustento da família',
#        'Tenho renda, recebo ajuda de familiares ou outros',
#        'Tenho renda e não preciso de ajuda',
#        'Sem renda, financiado por programas de governo'], dtype=object)

# %%
interest_data['q10'].unique()
# Out:
# array(['Não estou trabalhando', 'Trabalho 40 horas semanais ou mais',
#        'Trabalho eventualmente', 'Trabalho de 21 a 39 horas semanais',
#        'Trabalho até 20 horas semanais'], dtype=object)

# %%
interest_data['q15'].unique()
# Out:
# array(['Não entrei por cotas', 'Entrei com cotas'], dtype=object)

# %%
interest_data['q17'].unique()
# Out:
# array(['EM: Todo em escola pública',
#        'EM: Todo em escola privada (particular)',
#        'EM: A maior parte em escola privada (particular)',
#        'EM: A maior parte em escola pública', 'EM: Todo no exterior',
#        'EM: Parte no Brasil e parte no exterior'], dtype=object)

# %%
interest_data['q21'].unique()
# Out:
# array(['Tenho familiar com graduação', 'Não tenho familiar com graduação'],
#       dtype=object)

# %%
interest_data['q58'].unique()
# Out:
# array(['IE Usou TICs: Concordo totalmente',
#        'IE Usou TICs: Discordo parcialmente', 'IE Usou TICs: Concordo',
#        'IE Usou TICs: Discordo', 'IE Usou TICs: Concordo parcialmente',
#        'IE Usou TICs: Discordo totalmente',
#        'IE Usou TICs: Não sei responder', 'IE Usou TICs: Não se aplica'],
#       dtype=object)

# %% [markdown]
# ## Generate histograms by grade z-score

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

data = interest_data['Z_SCORE_NOTA'].to_numpy()

mu, std = norm.fit(data)

# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)

plt.plot(x, p, 'k', linewidth=2)

plt.show()

# %% [markdown]
# ## Generate histograms by grade

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

data = interest_data['NOTA_GERAL'].to_numpy()

mu, std = norm.fit(data)

# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)

plt.plot(x, p, 'k', linewidth=2)

plt.show()

# %% [markdown]
# ## Filter by grades far above or far below average

# %%
filtered_interest_data = interest_data.query("Z_SCORE_NOTA > 2.00 or Z_SCORE_NOTA < -2.00")
filtered_interest_data.count()
# Out:
# no_categoria_administrativa_ies    17982
# no_organizacao_academica_ies       17982
# no_regiao_ies                      17982
# no_grau_academico                  17982
# no_modalidade                      17982
# faixa_etaria                       17982
# tp_sexo                            17982
# no_pres                            17982
# nt_ger                             17982
# q1                                 17982
# q2                                 17982
# q4                                 17982
# q5                                 17982
# q8                                 17982
# q9                                 17982
# q10                                17982
# q15                                17982
# q17                                17982
# q21                                17982
# q58                                17982
# NOTA_GERAL                         17982
# Z_SCORE_NOTA                       17982
# CLASSIFICACAO_NOTA                 17982
# dtype: int64

# %%
analysis_interest_columns = [
    'CLASSIFICACAO_NOTA',
    'no_categoria_administrativa_ies',
    'no_organizacao_academica_ies',
    'no_regiao_ies',
    'no_grau_academico',
    'no_modalidade',
    'faixa_etaria',
    'tp_sexo',
    'no_pres',
    'nt_ger',
    'q1', # Estado civil
    'q2', # Cor ou raça
    'q4', # Escolaridade do pai
    'q5', # Escolaridade da mãe
    'q8', # Renda total da família
    'q9', # Situação financeira
    'q10', # Situação de trabalho
    'q15', # Entrou por alguma política afirmativa?
    'q17', # Em que tipo de escola cursou o EM?
    'q21', # Alguém da família concluiu ensino superior?
    'q58', # Docentes utilizaram TICs como estratégia de ensino?
]

analysis_interest_data = filtered_interest_data[analysis_interest_columns]

# %% [markdown]
# ## Save a CSV file with the analysis interest data

# %%
import os

os.makedirs('analysis_interest_data', exist_ok=True)
analysis_interest_data.to_csv('analysis_interest_data/analysis-interest-data-2017.csv')

analysis_file_data = pd.read_csv('analysis_interest_data/analysis-interest-data-2017.csv', sep=',', encoding='UTF-8')
analysis_file_data.head()
# Out:
#    Unnamed: 0           CLASSIFICACAO_NOTA no_categoria_administrativa_ies  \
# 0       86569  NOTA: MUITO ABAIXO DA MÉDIA                 Pública Federal
# 1       86571  NOTA: MUITO ABAIXO DA MÉDIA                 Pública Federal
# 2       86609  NOTA: MUITO ABAIXO DA MÉDIA     Privada com fins lucrativos
# 3       86647  NOTA: MUITO ABAIXO DA MÉDIA     Privada com fins lucrativos
# 4       86852  NOTA: MUITO ABAIXO DA MÉDIA                 Pública Federal
#
#   no_organizacao_academica_ies no_regiao_ies no_grau_academico no_modalidade  \
# 0                 Universidade         Norte      Licenciatura           EaD
# 1                 Universidade         Norte      Licenciatura           EaD
# 2                    Faculdade         Norte      Licenciatura           EaD
# 3                    Faculdade         Norte      Licenciatura           EaD
# 4                 Universidade         Norte      Licenciatura           EaD
#
#          faixa_etaria    tp_sexo                        no_pres  ...  \
# 0  Entre 42 e 49 anos   Feminino  Presente com resultado válido  ...
# 1  Entre 42 e 49 anos   Feminino  Presente com resultado válido  ...
# 2  Entre 26 e 33 anos   Feminino  Presente com resultado válido  ...
# 3  Entre 34 e 41 anos   Feminino  Presente com resultado válido  ...
# 4  Entre 26 e 33 anos  Masculino  Presente com resultado válido  ...
#
#                        q2                         q4  \
# 0                  Branca  Pai: Nenhuma escolaridade
# 1  Raça/Cor não declarada  Pai: Nenhuma escolaridade
# 2                   Parda          Pai: Ensino Médio
# 3                   Parda  Pai: Ensino Fundamental I
# 4                   Parda          Pai: Ensino Médio
#
#                           q5               q8  \
# 0  Mãe: Nenhuma escolaridade  Classe Social D
# 1  Mãe: Ensino Fundamental I  Classe Social E
# 2          Mãe: Ensino Médio  Classe Social D
# 3          Mãe: Ensino Médio  Classe Social E
# 4  Mãe: Ensino Fundamental I  Classe Social C
#
#                                                   q9  \
# 0  Sou o principal responsável pelo sustento da f...
# 1  Tenho renda e contribuo com o sustento da família
# 2  Sou o principal responsável pelo sustento da f...
# 3  Tenho renda, recebo ajuda de familiares ou outros
# 4  Sou o principal responsável pelo sustento da f...
#
#                                   q10                   q15  \
# 0  Trabalho 40 horas semanais ou mais      Entrei com cotas
# 1      Trabalho até 20 horas semanais  Não entrei por cotas
# 2  Trabalho 40 horas semanais ou mais  Não entrei por cotas
# 3              Trabalho eventualmente  Não entrei por cotas
# 4  Trabalho 40 horas semanais ou mais      Entrei com cotas
#
#                           q17                               q21  \
# 0  EM: Todo em escola pública  Não tenho familiar com graduação
# 1  EM: Todo em escola pública  Não tenho familiar com graduação
# 2  EM: Todo em escola pública      Tenho familiar com graduação
# 3  EM: Todo em escola pública      Tenho familiar com graduação
# 4  EM: Todo em escola pública  Não tenho familiar com graduação
#
#                                  q58
# 0  IE Usou TICs: Concordo totalmente
# 1  IE Usou TICs: Discordo totalmente
# 2  IE Usou TICs: Concordo totalmente
# 3  IE Usou TICs: Concordo totalmente
# 4  IE Usou TICs: Concordo totalmente
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Convert table to transactions

# %%
transactions = analysis_interest_data.to_numpy()
transactions
# Out:
# array([['NOTA: MUITO ABAIXO DA MÉDIA', 'Pública Federal', 'Universidade',
#         ..., 'EM: Todo em escola pública',
#         'Não tenho familiar com graduação',
#         'IE Usou TICs: Concordo totalmente'],
#        ['NOTA: MUITO ABAIXO DA MÉDIA', 'Pública Federal', 'Universidade',
#         ..., 'EM: Todo em escola pública',
#         'Não tenho familiar com graduação',
#         'IE Usou TICs: Discordo totalmente'],
#        ['NOTA: MUITO ABAIXO DA MÉDIA', 'Privada com fins lucrativos',
#         'Faculdade', ..., 'EM: Todo em escola pública',
#         'Tenho familiar com graduação',
#         'IE Usou TICs: Concordo totalmente'],
#        ...,
#        ['NOTA: MUITO ACIMA DA MÉDIA', 'Pública Federal',
#         'Instituto Federal de Educação, Ciência e Tecnologia', ...,
#         'EM: Todo em escola pública', 'Tenho familiar com graduação',
#         'IE Usou TICs: Concordo totalmente'],
#        ['NOTA: MUITO ACIMA DA MÉDIA', 'Pública Federal',
#         'Instituto Federal de Educação, Ciência e Tecnologia', ...,
#         'EM: Todo em escola pública', 'Tenho familiar com graduação',
#         'IE Usou TICs: Concordo'],
#        ['NOTA: MUITO ACIMA DA MÉDIA', 'Pública Federal',
#         'Instituto Federal de Educação, Ciência e Tecnologia', ...,
#         'EM: Todo em escola pública', 'Tenho familiar com graduação',
#         'IE Usou TICs: Concordo totalmente']], dtype=object)

# %% [markdown]
# ## Create apriori rules

# %%
# %run '../scripts/apriori-params-setup.py'
rules = apriori(transactions, min_support=support, min_confidence=confidence)
rules
# Out:
# <generator object apriori at 0x177a32b30>

# %% [markdown]
# ## Run apriori

# %%
from datetime import datetime

initial_time = datetime.now()

results = pd.DataFrame(list(rules))

execution_time = datetime.now() - initial_time
print("Time to run apriori: " + str(execution_time))
# Out:
# Time to run apriori: 0:10:48.894771

# %%
results
# Out:
#                                                    items   support  \
# 0                                               (Branca)  0.570960
# 1                           (EM: Todo em escola pública)  0.584918
# 2                                             (Feminino)  0.513625
# 3                    (IE Usou TICs: Concordo totalmente)  0.507730
# 4                                         (Licenciatura)  0.549883
# ...                                                  ...       ...
# 16969  (NOTA: MUITO ACIMA DA MÉDIA, Entre 17 e 25 ano...  0.105606
# 16970  (NOTA: MUITO ACIMA DA MÉDIA, Entre 17 e 25 ano...  0.106495
# 16971  (NOTA: MUITO ACIMA DA MÉDIA, Entre 17 e 25 ano...  0.115894
# 16972  (NOTA: MUITO ACIMA DA MÉDIA, Entre 17 e 25 ano...  0.102158
# 16973  (NOTA: MUITO ACIMA DA MÉDIA, Entre 17 e 25 ano...  0.104549
#
#                                       ordered_statistics
# 0              [((), (Branca), 0.5709598487376265, 1.0)]
# 1      [((), (EM: Todo em escola pública), 0.58491825...
# 2            [((), (Feminino), 0.5136247358469581, 1.0)]
# 3      [((), (IE Usou TICs: Concordo totalmente), 0.5...
# 4        [((), (Licenciatura), 0.5498832165498833, 1.0)]
# ...                                                  ...
# 16969  [((Não estou trabalhando, Bacharelado, Entre 1...
# 16970  [((Pública Federal, Bacharelado), (NOTA: MUITO...
# 16971  [((EM: Todo em escola privada (particular), En...
# 16972  [((EM: Todo em escola privada (particular), Nã...
# 16973  [((Pública Federal, EM: Todo em escola privada...
#
# [16974 rows x 3 columns]

# %% [markdown]
# ## Extract results to a new table

# %%
from datetime import datetime

initial_time = datetime.now()

# %run '../scripts/extractor.py'

organized_rules = extractor(results)

execution_time = datetime.now() - initial_time
print("Time to run extractor: " + str(execution_time))

organized_rules
# Out:
# Time to run extractor: 0:00:05.028683
#                                                items_base  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 394524  [NOTA: MUITO ACIMA DA MÉDIA, Entre 17 e 25 ano...
# 394525  [NOTA: MUITO ACIMA DA MÉDIA, Entre 17 e 25 ano...
# 394526  [Entre 17 e 25 anos, Presencial, Solteiro(a), ...
# 394527  [NOTA: MUITO ACIMA DA MÉDIA, Presencial, Solte...
# 394528  [NOTA: MUITO ACIMA DA MÉDIA, Entre 17 e 25 ano...
#
#                                         items_add   support  confidence  \
# 0                                        [Branca]  0.570960    0.570960
# 1                    [EM: Todo em escola pública]  0.584918    0.584918
# 2                                      [Feminino]  0.513625    0.513625
# 3             [IE Usou TICs: Concordo totalmente]  0.507730    0.507730
# 4                                  [Licenciatura]  0.549883    0.549883
# ...                                           ...       ...         ...
# 394524                               [Presencial]  0.104549    0.999468
# 394525                     [Não entrei por cotas]  0.104549    0.992608
# 394526               [NOTA: MUITO ACIMA DA MÉDIA]  0.104549    0.954799
# 394527                       [Entre 17 e 25 anos]  0.104549    0.835556
# 394528  [EM: Todo em escola privada (particular)]  0.104549    0.775578
#
#             lift
# 0       1.000000
# 1       1.000000
# 2       1.000000
# 3       1.000000
# 4       1.000000
# ...          ...
# 394524  1.263263
# 394525  1.253007
# 394526  1.449122
# 394527  1.673904
# 394528  2.283306
#
# [394529 rows x 5 columns]

# %%
rules_count = len(organized_rules.index)
print("Count of itemsets: " + str(len(results.index)))
print("Count of association rules for support " + str((support *100)) + "% and confidence " + str((confidence * 100)) + "%: " + str(rules_count))
# Out:
# Count of itemsets: 16974
# Count of association rules for support 10.0% and confidence 50.0%: 394529

# %% [markdown]
# ## Save results to a new CSV file

# %%
import os

os.makedirs('results', exist_ok=True)
organized_rules.to_csv('results/organized-associations-2017.csv')
