# %% [markdown]
# # Analysis from ENEM microdata for 2021

# %% [markdown]
# ## Import libs

# %%
import pandas as pd
from apyori import apriori

# %% [markdown]
# ## Read microdata file

# %%
data = pd.read_csv('../microdata/microdata-enem-2021.csv', sep=';', encoding='ISO-8859-1')
data
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210053865474    2021                5       F                1
# 1        210052384164    2021               12       M                1
# 2        210052589243    2021               13       F                3
# 3        210052128335    2021                3       M                1
# 4        210051353021    2021                2       F                1
# ...               ...     ...              ...     ...              ...
# 3389827  210053249138    2021                7       F                1
# 3389828  210053776013    2021                7       F                1
# 3389829  210052441508    2021               13       F                1
# 3389830  210051139675    2021                7       F                1
# 3389831  210052410399    2021               12       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 0                  1                 1                1                3
# 1                  1                 1                1               11
# 2                  1                 1                1               15
# 3                  3                 1                2                0
# 4                  3                 1                2                0
# ...              ...               ...              ...              ...
# 3389827            3                 1                1                0
# 3389828            1                 1                1                5
# 3389829            3                 1                1               15
# 3389830            1                 1                1                4
# 3389831            3                 1                1               15
#
#          TP_ESCOLA  ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  \
# 0                1  ...     A     A     A    B     A    A     B     A     B
# 1                1  ...     A     A     A    B     A    A     C     A     A
# 2                1  ...     B     A     A    B     A    A     C     B     B
# 3                2  ...     A     A     A    B     A    A     B     A     B
# 4                2  ...     B     A     A    B     A    B     E     A     B
# ...            ...  ...   ...   ...   ...  ...   ...  ...   ...   ...   ...
# 3389827          1  ...     A     A     A    B     A    A     B     A     A
# 3389828          1  ...     B     A     B    C     A    A     E     B     B
# 3389829          1  ...     B     A     A    A     A    A     B     A     B
# 3389830          1  ...     B     A     B    B     A    B     E     A     C
# 3389831          1  ...   NaN   NaN   NaN  NaN   NaN  NaN   NaN   NaN   NaN
#
#          Q025
# 0           B
# 1           A
# 2           B
# 3           B
# 4           B
# ...       ...
# 3389827     B
# 3389828     B
# 3389829     B
# 3389830     B
# 3389831   NaN
#
# [3389832 rows x 76 columns]

# %% [markdown]
# ## Select only columns of interest

# %%
interest_columns = [
    'TP_SEXO',
    'TP_ESTADO_CIVIL',
    'TP_COR_RACA',
    'TP_FAIXA_ETARIA',
    'TP_ST_CONCLUSAO',
    'TP_ESCOLA',
    'TP_DEPENDENCIA_ADM_ESC',
    'SG_UF_PROVA',
    'NU_NOTA_CN',
    'NU_NOTA_CH',
    'NU_NOTA_LC',
    'NU_NOTA_MT',
    'NU_NOTA_REDACAO',
    'Q001',
    'Q002',
    'Q006',
    'Q022',
    'Q024',
    'Q025'
]

interest_data = data[interest_columns]

interest_data.head()
# Out:
#   TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_FAIXA_ETARIA  TP_ST_CONCLUSAO  \
# 0       F                1            1                5                1
# 1       M                1            1               12                1
# 2       F                3            1               13                1
# 3       M                1            3                3                2
# 4       F                1            3                2                2
#
#    TP_ESCOLA  TP_DEPENDENCIA_ADM_ESC SG_UF_PROVA  NU_NOTA_CN  NU_NOTA_CH  \
# 0          1                     NaN          MG         NaN       574.6
# 1          1                     NaN          AL       505.9       551.8
# 2          1                     NaN          SP         NaN         NaN
# 3          2                     2.0          CE       580.7       678.9
# 4          2                     2.0          CE       497.7       532.4
#
#    NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002 Q006 Q022 Q024 Q025
# 0       472.6         NaN            760.0    F    F    D    B    B    B
# 1       498.3       461.5            560.0    B    B    B    C    A    A
# 2         NaN         NaN              NaN    B    C    C    C    B    B
# 3       638.9       659.5            780.0    B    B    B    B    B    B
# 4       457.6       582.6            780.0    D    E    C    E    B    B

# %% [markdown]
# ### Check count for valid values

# %%
interest_data.count()
# Out:
# TP_SEXO                   3389832
# TP_ESTADO_CIVIL           3389832
# TP_COR_RACA               3389832
# TP_FAIXA_ETARIA           3389832
# TP_ST_CONCLUSAO           3389832
# TP_ESCOLA                 3389832
# TP_DEPENDENCIA_ADM_ESC     813806
# SG_UF_PROVA               3389832
# NU_NOTA_CN                2245844
# NU_NOTA_CH                2378379
# NU_NOTA_LC                2378379
# NU_NOTA_MT                2245844
# NU_NOTA_REDACAO           2378379
# Q001                      3389830
# Q002                      3389830
# Q006                      3389830
# Q022                      3389830
# Q024                      3389830
# Q025                      3389830
# dtype: int64

# %% [markdown]
# ## Translate some columns to better readability

# %%
# %run '../scripts/attribute-dictionary.py'

interest_data = interest_data.fillna(value = {"TP_DEPENDENCIA_ADM_ESC": 0})
interest_data = interest_data.replace(dictionary_params)

interest_data.head()
# Out:
#      TP_SEXO                          TP_ESTADO_CIVIL TP_COR_RACA  \
# 0   Feminino                              Solteiro(a)      Branco
# 1  Masculino                              Solteiro(a)      Branco
# 2   Feminino  Divorciado(a)/Desquitado(a)/Separado(a)      Branco
# 3  Masculino                              Solteiro(a)       Pardo
# 4   Feminino                              Solteiro(a)       Pardo
#
#       TP_FAIXA_ETARIA                                TP_ST_CONCLUSAO  \
# 0  Entre 17 e 25 anos                      Já concluí o Ensino Médio
# 1  Entre 31 e 35 anos                      Já concluí o Ensino Médio
# 2  Entre 36 e 40 anos                      Já concluí o Ensino Médio
# 3  Entre 17 e 25 anos  Estou cursando e concluirei o Ensino este ano
# 4  Entre 17 e 25 anos  Estou cursando e concluirei o Ensino este ano
#
#        TP_ESCOLA                    TP_DEPENDENCIA_ADM_ESC      SG_UF_PROVA  \
# 0  Não Respondeu  Dependencia administrativa nao informada   Região Sudeste
# 1  Não Respondeu  Dependencia administrativa nao informada  Região Nordeste
# 2  Não Respondeu  Dependencia administrativa nao informada   Região Sudeste
# 3        Pública                                  Estadual  Região Nordeste
# 4        Pública                                  Estadual  Região Nordeste
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO  \
# 0         NaN       574.6       472.6         NaN            760.0
# 1       505.9       551.8       498.3       461.5            560.0
# 2         NaN         NaN         NaN         NaN              NaN
# 3       580.7       678.9       638.9       659.5            780.0
# 4       497.7       532.4       457.6       582.6            780.0
#
#                            Q001                           Q002  \
# 0        Pai Graduação completa         Mãe Graduação completa
# 1  Pai Fundamental I incompleto   Mãe Fundamental I incompleto
# 2  Pai Fundamental I incompleto  Mãe Fundamental II incompleto
# 3  Pai Fundamental I incompleto   Mãe Fundamental I incompleto
# 4   Pai Ensino médio incompleto      Mãe Ensino médio completo
#
#               Q006         Q022                Q024                      Q025
# 0  Classe Social E  Tem celular      Tem computador      Tem internet em casa
# 1  Classe Social E  Tem celular  Não tem computador  Não tem internet em casa
# 2  Classe Social E  Tem celular      Tem computador      Tem internet em casa
# 3  Classe Social E  Tem celular      Tem computador      Tem internet em casa
# 4  Classe Social E  Tem celular      Tem computador      Tem internet em casa

# %% [markdown]
# ## Remove nil values and creates a new column with the arithmetic average of the grades

# %%
interest_data = interest_data.query("NU_NOTA_CN.notnull() and NU_NOTA_CH.notnull() and NU_NOTA_LC.notnull() and NU_NOTA_MT.notnull() and NU_NOTA_REDACAO.notnull() and TP_ESTADO_CIVIL.notnull() and Q006.notnull() and Q022.notnull() and Q024.notnull() and Q025.notnull()")
interest_data["NU_NOTA_GERAL"] = interest_data[["NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_LC", "NU_NOTA_MT", "NU_NOTA_REDACAO"]].mean(axis=1)

interest_data.head()
# Out:
#      TP_SEXO TP_ESTADO_CIVIL TP_COR_RACA     TP_FAIXA_ETARIA  \
# 1  Masculino     Solteiro(a)      Branco  Entre 31 e 35 anos
# 3  Masculino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 4   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 8   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 9   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
#
#                                  TP_ST_CONCLUSAO      TP_ESCOLA  \
# 1                      Já concluí o Ensino Médio  Não Respondeu
# 3  Estou cursando e concluirei o Ensino este ano        Pública
# 4  Estou cursando e concluirei o Ensino este ano        Pública
# 8  Estou cursando e concluirei o Ensino este ano        Pública
# 9  Estou cursando e concluirei o Ensino este ano        Pública
#
#                      TP_DEPENDENCIA_ADM_ESC      SG_UF_PROVA  NU_NOTA_CN  \
# 1  Dependencia administrativa nao informada  Região Nordeste       505.9
# 3                                  Estadual  Região Nordeste       580.7
# 4                                  Estadual  Região Nordeste       497.7
# 8  Dependencia administrativa nao informada   Região Sudeste       487.4
# 9  Dependencia administrativa nao informada  Região Nordeste       507.6
#
#    NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO  \
# 1       551.8       498.3       461.5            560.0
# 3       678.9       638.9       659.5            780.0
# 4       532.4       457.6       582.6            780.0
# 8       476.5       450.7       493.4            520.0
# 9       539.2       494.6       413.3            380.0
#
#                            Q001                          Q002  \
# 1  Pai Fundamental I incompleto  Mãe Fundamental I incompleto
# 3  Pai Fundamental I incompleto  Mãe Fundamental I incompleto
# 4   Pai Ensino médio incompleto     Mãe Ensino médio completo
# 8  Pai Fundamental I incompleto  Mãe Fundamental I incompleto
# 9   Pai Ensino médio incompleto   Mãe Ensino médio incompleto
#
#               Q006         Q022                Q024                      Q025  \
# 1  Classe Social E  Tem celular  Não tem computador  Não tem internet em casa
# 3  Classe Social E  Tem celular      Tem computador      Tem internet em casa
# 4  Classe Social E  Tem celular      Tem computador      Tem internet em casa
# 8  Classe Social E  Tem celular  Não tem computador      Tem internet em casa
# 9  Classe Social E  Tem celular  Não tem computador      Tem internet em casa
#
#    NU_NOTA_GERAL
# 1         515.50
# 3         667.60
# 4         570.06
# 8         485.60
# 9         466.94

# %% [markdown]
# ### Check count for valid values

# %%
interest_data.count()
# Out:
# TP_SEXO                   2238106
# TP_ESTADO_CIVIL           2238106
# TP_COR_RACA               2238106
# TP_FAIXA_ETARIA           2238106
# TP_ST_CONCLUSAO           2238106
# TP_ESCOLA                 2238106
# TP_DEPENDENCIA_ADM_ESC    2238106
# SG_UF_PROVA               2238106
# NU_NOTA_CN                2238106
# NU_NOTA_CH                2238106
# NU_NOTA_LC                2238106
# NU_NOTA_MT                2238106
# NU_NOTA_REDACAO           2238106
# Q001                      2238106
# Q002                      2238106
# Q006                      2238106
# Q022                      2238106
# Q024                      2238106
# Q025                      2238106
# NU_NOTA_GERAL             2238106
# dtype: int64

# %% [markdown]
# ## Calculate Z-SCORE from NU_NOTA_GERAL

# %%
from scipy.stats import zscore

interest_data["Z_SCORE_NOTA"] = zscore(interest_data["NU_NOTA_GERAL"])
interest_data.head()
# Out:
#      TP_SEXO TP_ESTADO_CIVIL TP_COR_RACA     TP_FAIXA_ETARIA  \
# 1  Masculino     Solteiro(a)      Branco  Entre 31 e 35 anos
# 3  Masculino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 4   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 8   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 9   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
#
#                                  TP_ST_CONCLUSAO      TP_ESCOLA  \
# 1                      Já concluí o Ensino Médio  Não Respondeu
# 3  Estou cursando e concluirei o Ensino este ano        Pública
# 4  Estou cursando e concluirei o Ensino este ano        Pública
# 8  Estou cursando e concluirei o Ensino este ano        Pública
# 9  Estou cursando e concluirei o Ensino este ano        Pública
#
#                      TP_DEPENDENCIA_ADM_ESC      SG_UF_PROVA  NU_NOTA_CN  \
# 1  Dependencia administrativa nao informada  Região Nordeste       505.9
# 3                                  Estadual  Região Nordeste       580.7
# 4                                  Estadual  Região Nordeste       497.7
# 8  Dependencia administrativa nao informada   Região Sudeste       487.4
# 9  Dependencia administrativa nao informada  Região Nordeste       507.6
#
#    NU_NOTA_CH  ...  NU_NOTA_MT  NU_NOTA_REDACAO                          Q001  \
# 1       551.8  ...       461.5            560.0  Pai Fundamental I incompleto
# 3       678.9  ...       659.5            780.0  Pai Fundamental I incompleto
# 4       532.4  ...       582.6            780.0   Pai Ensino médio incompleto
# 8       476.5  ...       493.4            520.0  Pai Fundamental I incompleto
# 9       539.2  ...       413.3            380.0   Pai Ensino médio incompleto
#
#                            Q002             Q006         Q022  \
# 1  Mãe Fundamental I incompleto  Classe Social E  Tem celular
# 3  Mãe Fundamental I incompleto  Classe Social E  Tem celular
# 4     Mãe Ensino médio completo  Classe Social E  Tem celular
# 8  Mãe Fundamental I incompleto  Classe Social E  Tem celular
# 9   Mãe Ensino médio incompleto  Classe Social E  Tem celular
#
#                  Q024                      Q025 NU_NOTA_GERAL  Z_SCORE_NOTA
# 1  Não tem computador  Não tem internet em casa        515.50     -0.225270
# 3      Tem computador      Tem internet em casa        667.60      1.484460
# 4      Tem computador      Tem internet em casa        570.06      0.388030
# 8  Não tem computador      Tem internet em casa        485.60     -0.561371
# 9  Não tem computador      Tem internet em casa        466.94     -0.771125
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Z-SCORE mínimo

# %%
interest_data["Z_SCORE_NOTA"].min()
# Out:
# -6.019917348317704

# %% [markdown]
# ### Z-SCORE máximo

# %%
interest_data["Z_SCORE_NOTA"].max()
# Out:
# 3.677320823466754

# %% [markdown]
# ## Create a label for grade based on z-score

# %%
NOTA_GERAL_LABELS = [
  "NOTA: MUITO ABAIXO DA MÉDIA",
  "NOTA: ABAIXO DA MÉDIA",
  "NOTA: MÉDIA",
  "NOTA: ACIMA DA MÉDIA",
  "NOTA: MUITO ACIMA DA MÉDIA",
]

interest_data["CLASSIFICACAO_NOTA"] = pd.cut(interest_data["Z_SCORE_NOTA"], bins=[-10, -2, -1, 1, 2, 10], labels=NOTA_GERAL_LABELS)

interest_data.head()
# Out:
#      TP_SEXO TP_ESTADO_CIVIL TP_COR_RACA     TP_FAIXA_ETARIA  \
# 1  Masculino     Solteiro(a)      Branco  Entre 31 e 35 anos
# 3  Masculino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 4   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 8   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 9   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
#
#                                  TP_ST_CONCLUSAO      TP_ESCOLA  \
# 1                      Já concluí o Ensino Médio  Não Respondeu
# 3  Estou cursando e concluirei o Ensino este ano        Pública
# 4  Estou cursando e concluirei o Ensino este ano        Pública
# 8  Estou cursando e concluirei o Ensino este ano        Pública
# 9  Estou cursando e concluirei o Ensino este ano        Pública
#
#                      TP_DEPENDENCIA_ADM_ESC      SG_UF_PROVA  NU_NOTA_CN  \
# 1  Dependencia administrativa nao informada  Região Nordeste       505.9
# 3                                  Estadual  Região Nordeste       580.7
# 4                                  Estadual  Região Nordeste       497.7
# 8  Dependencia administrativa nao informada   Região Sudeste       487.4
# 9  Dependencia administrativa nao informada  Região Nordeste       507.6
#
#    NU_NOTA_CH  ...  NU_NOTA_REDACAO                          Q001  \
# 1       551.8  ...            560.0  Pai Fundamental I incompleto
# 3       678.9  ...            780.0  Pai Fundamental I incompleto
# 4       532.4  ...            780.0   Pai Ensino médio incompleto
# 8       476.5  ...            520.0  Pai Fundamental I incompleto
# 9       539.2  ...            380.0   Pai Ensino médio incompleto
#
#                            Q002             Q006         Q022  \
# 1  Mãe Fundamental I incompleto  Classe Social E  Tem celular
# 3  Mãe Fundamental I incompleto  Classe Social E  Tem celular
# 4     Mãe Ensino médio completo  Classe Social E  Tem celular
# 8  Mãe Fundamental I incompleto  Classe Social E  Tem celular
# 9   Mãe Ensino médio incompleto  Classe Social E  Tem celular
#
#                  Q024                      Q025 NU_NOTA_GERAL Z_SCORE_NOTA  \
# 1  Não tem computador  Não tem internet em casa        515.50    -0.225270
# 3      Tem computador      Tem internet em casa        667.60     1.484460
# 4      Tem computador      Tem internet em casa        570.06     0.388030
# 8  Não tem computador      Tem internet em casa        485.60    -0.561371
# 9  Não tem computador      Tem internet em casa        466.94    -0.771125
#
#      CLASSIFICACAO_NOTA
# 1           NOTA: MÉDIA
# 3  NOTA: ACIMA DA MÉDIA
# 4           NOTA: MÉDIA
# 8           NOTA: MÉDIA
# 9           NOTA: MÉDIA
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Check for uniqueness of all values to check if all of them was translated

# %%
interest_data['TP_SEXO'].unique()
# Out:
# array(['Masculino', 'Feminino'], dtype=object)

# %%
interest_data['TP_ESTADO_CIVIL'].unique()
# Out:
# array(['Solteiro(a)', 'Casado(a) ou mora com companheiro(a)',
#        'Divorciado(a)/Desquitado(a)/Separado(a)',
#        'Estado civil: Não informado', 'Viúvo(a)'], dtype=object)

# %%
interest_data['TP_COR_RACA'].unique()
# Out:
# array(['Branco', 'Pardo', 'Preto', 'Amarelo', 'Indígena',
#        'Cor/Raça Não Declarado', 6], dtype=object)

# %%
interest_data['TP_FAIXA_ETARIA'].unique()
# Out:
# array(['Entre 31 e 35 anos', 'Entre 17 e 25 anos', 'Entre 26 e 30 anos',
#        'Entre 36 e 40 anos', 'Menor de 17 anos', 'Entre 41 e 45 anos',
#        'Entre 51 e 55 anos', 'Entre 46 e 50 anos', 'Entre 56 e 60 anos',
#        'Entre 61 e 65 anos', 'Entre 66 e 70 anos', 'Maior de 70 anos'],
#       dtype=object)

# %%
interest_data['TP_ST_CONCLUSAO'].unique()
# Out:
# array(['Já concluí o Ensino Médio',
#        'Estou cursando e concluirei o Ensino este ano',
#        'Estou cursando e concluirei o Ensino Médio após este ano',
#        'Não concluí e não estou cursando o Ensino Médio'], dtype=object)

# %%
interest_data['TP_ESCOLA'].unique()
# Out:
# array(['Não Respondeu', 'Pública', 'Privada'], dtype=object)

# %%
interest_data['TP_DEPENDENCIA_ADM_ESC'].unique()
# Out:
# array(['Dependencia administrativa nao informada', 'Estadual', 'Federal',
#        'Privada', 'Municipal'], dtype=object)

# %%
interest_data['SG_UF_PROVA'].unique()
# Out:
# array(['Região Nordeste', 'Região Sudeste', 'Região Centro-Oeste',
#        'Região Norte', 'Região Sul'], dtype=object)

# %%
interest_data['Q001'].unique()
# Out:
# array(['Pai Fundamental I incompleto', 'Pai Ensino médio incompleto',
#        'Pai Ensino médio completo', 'Pai Fundamental II incompleto',
#        'Pai Pós-graduação completa', 'Não sei a escolaridade do meu pai',
#        'Pai Graduação completa', 'Pai nunca estudou'], dtype=object)

# %%
interest_data['Q002'].unique()
# Out:
# array(['Mãe Fundamental I incompleto', 'Mãe Ensino médio completo',
#        'Mãe Ensino médio incompleto', 'Mãe Fundamental II incompleto',
#        'Mãe Graduação completa', 'Mãe Pós-graduação completa',
#        'Mãe nunca estudou', 'Não sei a escolaridade da minha mãe'],
#       dtype=object)

# %%
interest_data['Q006'].unique()
# Out:
# array(['Classe Social E', 'Classe Social D', 'Classe Social C',
#        'Classe Social B', 'Classe Social A'], dtype=object)

# %%
interest_data['Q022'].unique()
# Out:
# array(['Tem celular', 'Não tem celular'], dtype=object)

# %%
interest_data['Q024'].unique()
# Out:
# array(['Não tem computador', 'Tem computador'], dtype=object)

# %%
interest_data['Q025'].unique()
# Out:
# array(['Não tem internet em casa', 'Tem internet em casa'], dtype=object)

# %%
interest_data['CLASSIFICACAO_NOTA'].unique()
# Out:
# ['NOTA: MÉDIA', 'NOTA: ACIMA DA MÉDIA', 'NOTA: MUITO ACIMA DA MÉDIA', 'NOTA: ABAIXO DA MÉDIA', 'NOTA: MUITO ABAIXO DA MÉDIA']
# Categories (5, object): ['NOTA: MUITO ABAIXO DA MÉDIA' < 'NOTA: ABAIXO DA MÉDIA' < 'NOTA: MÉDIA' < 'NOTA: ACIMA DA MÉDIA' < 'NOTA: MUITO ACIMA DA MÉDIA']

# %% [markdown]
# ## Generate histograms by grade z-score

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

data = interest_data['Z_SCORE_NOTA'].to_numpy()

mu, std = norm.fit(data) 
  
# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k', linewidth=2)
  
plt.show()

# %% [markdown]
# ## Generate histograms by grade

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

data = interest_data['NU_NOTA_GERAL'].to_numpy()

mu, std = norm.fit(data) 
  
# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k', linewidth=2)
  
plt.show()

# %% [markdown]
# ## Filter by grades far above or far below average

# %%
filtered_interest_data = interest_data.query("Z_SCORE_NOTA > 2.00 or Z_SCORE_NOTA < -2.00")
filtered_interest_data.count()
# Out:
# TP_SEXO                   110263
# TP_ESTADO_CIVIL           110263
# TP_COR_RACA               110263
# TP_FAIXA_ETARIA           110263
# TP_ST_CONCLUSAO           110263
# TP_ESCOLA                 110263
# TP_DEPENDENCIA_ADM_ESC    110263
# SG_UF_PROVA               110263
# NU_NOTA_CN                110263
# NU_NOTA_CH                110263
# NU_NOTA_LC                110263
# NU_NOTA_MT                110263
# NU_NOTA_REDACAO           110263
# Q001                      110263
# Q002                      110263
# Q006                      110263
# Q022                      110263
# Q024                      110263
# Q025                      110263
# NU_NOTA_GERAL             110263
# Z_SCORE_NOTA              110263
# CLASSIFICACAO_NOTA        110263
# dtype: int64

# %%
analysis_interest_columns = [
    'TP_SEXO',
    'TP_ESTADO_CIVIL',
    'TP_COR_RACA',
    'TP_FAIXA_ETARIA',
    'TP_ST_CONCLUSAO',
    'TP_ESCOLA',
    'TP_DEPENDENCIA_ADM_ESC',
    'SG_UF_PROVA',
    'CLASSIFICACAO_NOTA',
    'Q001',
    'Q002',
    'Q006',
    'Q022',
    'Q024',
    'Q025'
]

analysis_interest_data = filtered_interest_data[analysis_interest_columns]

# %% [markdown]
# ## Save a CSV file with the analysis interest data

# %%
import os  

os.makedirs('analysis_interest_data', exist_ok=True)  
analysis_interest_data.to_csv('analysis_interest_data/analysis-interest-data-2021.csv')

analysis_file_data = pd.read_csv('analysis_interest_data/analysis-interest-data-2021.csv', sep=',', encoding='UTF-8')
analysis_file_data.head()
# Out:
#    Unnamed: 0    TP_SEXO TP_ESTADO_CIVIL TP_COR_RACA     TP_FAIXA_ETARIA  \
# 0          10   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 1          56  Masculino     Solteiro(a)      Branco  Entre 17 e 25 anos
# 2          65   Feminino     Solteiro(a)       Preto  Entre 17 e 25 anos
# 3          79   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 4         105  Masculino     Solteiro(a)       Pardo  Entre 17 e 25 anos
#
#                                  TP_ST_CONCLUSAO      TP_ESCOLA  \
# 0                      Já concluí o Ensino Médio  Não Respondeu
# 1                      Já concluí o Ensino Médio  Não Respondeu
# 2  Estou cursando e concluirei o Ensino este ano        Pública
# 3                      Já concluí o Ensino Médio  Não Respondeu
# 4                      Já concluí o Ensino Médio  Não Respondeu
#
#                      TP_DEPENDENCIA_ADM_ESC          SG_UF_PROVA  \
# 0  Dependencia administrativa nao informada  Região Centro-Oeste
# 1  Dependencia administrativa nao informada       Região Sudeste
# 2  Dependencia administrativa nao informada  Região Centro-Oeste
# 3  Dependencia administrativa nao informada       Região Sudeste
# 4  Dependencia administrativa nao informada       Região Sudeste
#
#             CLASSIFICACAO_NOTA                           Q001  \
# 0   NOTA: MUITO ACIMA DA MÉDIA      Pai Ensino médio completo
# 1   NOTA: MUITO ACIMA DA MÉDIA      Pai Ensino médio completo
# 2  NOTA: MUITO ABAIXO DA MÉDIA   Pai Fundamental I incompleto
# 3   NOTA: MUITO ACIMA DA MÉDIA    Pai Ensino médio incompleto
# 4   NOTA: MUITO ACIMA DA MÉDIA  Pai Fundamental II incompleto
#
#                             Q002             Q006         Q022  \
# 0      Mãe Ensino médio completo  Classe Social E  Tem celular
# 1         Mãe Graduação completa  Classe Social D  Tem celular
# 2      Mãe Ensino médio completo  Classe Social D  Tem celular
# 3     Mãe Pós-graduação completa  Classe Social D  Tem celular
# 4  Mãe Fundamental II incompleto  Classe Social E  Tem celular
#
#                  Q024                  Q025
# 0      Tem computador  Tem internet em casa
# 1      Tem computador  Tem internet em casa
# 2  Não tem computador  Tem internet em casa
# 3      Tem computador  Tem internet em casa
# 4  Não tem computador  Tem internet em casa

# %% [markdown]
# ## Convert table to transactions

# %%
transactions = analysis_interest_data.to_numpy()
transactions
# Out:
# array([['Feminino', 'Solteiro(a)', 'Pardo', ..., 'Tem celular',
#         'Tem computador', 'Tem internet em casa'],
#        ['Masculino', 'Solteiro(a)', 'Branco', ..., 'Tem celular',
#         'Tem computador', 'Tem internet em casa'],
#        ['Feminino', 'Solteiro(a)', 'Preto', ..., 'Tem celular',
#         'Não tem computador', 'Tem internet em casa'],
#        ...,
#        ['Feminino', 'Solteiro(a)', 'Preto', ..., 'Tem celular',
#         'Tem computador', 'Tem internet em casa'],
#        ['Masculino', 'Estado civil: Não informado', 'Preto', ...,
#         'Tem celular', 'Tem computador', 'Tem internet em casa'],
#        ['Feminino', 'Solteiro(a)', 'Branco', ..., 'Tem celular',
#         'Não tem computador', 'Tem internet em casa']], dtype=object)

# %% [markdown]
# ## Create apriori rules

# %%
# %run '../scripts/apriori-params-setup.py'
rules = apriori(transactions, min_support=support, min_confidence=confidence)
rules
# Out:
# <generator object apriori at 0x2ffca4d60>

# %% [markdown]
# ## Run apriori

# %%
from datetime import datetime

initial_time = datetime.now()

results = pd.DataFrame(list(rules))

execution_time = datetime.now() - initial_time
print("Time to run apriori: " + str(execution_time))
# Out:
# Time to run apriori: 1:26:13.179370

# %%
results
# Out:
#                                                    items   support  \
# 0                                               (Branco)  0.540798
# 1             (Dependencia administrativa nao informada)  0.706175
# 2                                   (Entre 17 e 25 anos)  0.842114
# 3                                             (Feminino)  0.548724
# 4                            (Já concluí o Ensino Médio)  0.534431
# ...                                                  ...       ...
# 12010  (Entre 17 e 25 anos, Não Respondeu, NOTA: MUIT...  0.107343
# 12011  (Entre 17 e 25 anos, Não Respondeu, NOTA: MUIT...  0.163591
# 12012  (Não Respondeu, NOTA: MUITO ACIMA DA MÉDIA, Te...  0.104849
# 12013  (Entre 17 e 25 anos, Branco, NOTA: MUITO ACIMA...  0.146359
# 12014  (Entre 17 e 25 anos, Branco, NOTA: MUITO ACIMA...  0.124920
#
#                                       ordered_statistics
# 0              [((), (Branco), 0.5407979104504684, 1.0)]
# 1      [((), (Dependencia administrativa nao informad...
# 2      [((), (Entre 17 e 25 anos), 0.8421138550556397...
# 3            [((), (Feminino), 0.5487244134478474, 1.0)]
# 4      [((), (Já concluí o Ensino Médio), 0.534431314...
# ...                                                  ...
# 12010  [((Dependencia administrativa nao informada, P...
# 12011  [((Dependencia administrativa nao informada, R...
# 12012  [((Feminino, Região Sudeste), (Não Respondeu, ...
# 12013  [((Dependencia administrativa nao informada, B...
# 12014  [((Já concluí o Ensino Médio, Região Sudeste),...
#
# [12015 rows x 3 columns]

# %% [markdown]
# ## Extract results to a new table

# %%
from datetime import datetime

initial_time = datetime.now()

# %run '../scripts/extractor.py'

organized_rules = extractor(results)

execution_time = datetime.now() - initial_time
print("Time to run extractor: " + str(execution_time))

organized_rules
# Out:
# Time to run extractor: 0:00:05.301512
#                                                items_base  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 411152  [Entre 17 e 25 anos, Branco, Não Respondeu, Te...
# 411153  [Entre 17 e 25 anos, Não Respondeu, Branco, NO...
# 411154  [Branco, NOTA: MUITO ACIMA DA MÉDIA, Não Respo...
# 411155  [Entre 17 e 25 anos, Branco, NOTA: MUITO ACIMA...
# 411156  [Entre 17 e 25 anos, Não Respondeu, NOTA: MUIT...
#
#                                          items_add   support  confidence  \
# 0                                         [Branco]  0.540798    0.540798
# 1       [Dependencia administrativa nao informada]  0.706175    0.706175
# 2                             [Entre 17 e 25 anos]  0.842114    0.842114
# 3                                       [Feminino]  0.548724    0.548724
# 4                      [Já concluí o Ensino Médio]  0.534431    0.534431
# ...                                            ...       ...         ...
# 411152                [NOTA: MUITO ACIMA DA MÉDIA]  0.124920    0.979589
# 411153                 [Já concluí o Ensino Médio]  0.124920    0.957525
# 411154                        [Entre 17 e 25 anos]  0.124920    0.932061
# 411155  [Dependencia administrativa nao informada]  0.124920    1.000000
# 411156                                    [Branco]  0.124920    0.763610
#
#             lift
# 0       1.000000
# 1       1.000000
# 2       1.000000
# 3       1.000000
# 4       1.000000
# ...          ...
# 411152  1.516645
# 411153  1.791671
# 411154  1.106811
# 411155  1.416079
# 411156  1.412006
#
# [411157 rows x 5 columns]

# %%
rules_count = len(organized_rules.index)
print("Count of itemsets: " + str(len(results.index)))
print("Count of association rules for support " + str((support *100)) + "% and confidence " + str((confidence * 100)) + "%: " + str(rules_count))
# Out:
# Count of itemsets: 12015
# Count of association rules for support 10.0% and confidence 50.0%: 411157

# %% [markdown]
# ## Save results to a new CSV file

# %%
import os  

os.makedirs('results', exist_ok=True)  
organized_rules.to_csv('results/organized-associations-2021.csv')
