# %% [markdown]
# # General analysis from association rules

# %% [markdown]
# ## Import all rules results

# %%
# %run '../scripts/import-all-rules-results.py'

all_rules
# Out:
#                                                 items_base  \
# 0                                                       []
# 1                                                       []
# 2                                                       []
# 3                                                       []
# 4                                                       []
# ...                                                    ...
# 1460629  ['Solteiro(a)', 'Branco', 'Tem computador', 'N...
# 1460630  ['Solteiro(a)', 'Branco', 'Tem computador', 'J...
# 1460631  ['Solteiro(a)', 'Branco', 'Tem computador', 'J...
# 1460632  ['Solteiro(a)', 'Branco', 'Tem computador', 'J...
# 1460633  ['Solteiro(a)', 'Tem computador', 'Já concluí ...
#
#                                             items_add   support  confidence  \
# 0        ['Dependencia administrativa nao informada']  0.713842    0.713842
# 1                              ['Entre 17 e 25 anos']  0.813179    0.813179
# 2                                        ['Feminino']  0.537954    0.537954
# 3                       ['Já concluí o Ensino Médio']  0.528198    0.528198
# 4                      ['NOTA: MUITO ACIMA DA MÉDIA']  0.644401    0.644401
# ...                                               ...       ...         ...
# 1460629                 ['Já concluí o Ensino Médio']  0.111337    0.967369
# 1460630                                  ['Feminino']  0.111337    0.594778
# 1460631                        ['Entre 17 e 25 anos']  0.111337    0.949476
# 1460632  ['Dependencia administrativa nao informada']  0.111337    1.000000
# 1460633                                    ['Branco']  0.111337    0.731392
#
#              lift  year
# 0        1.000000  2019
# 1        1.000000  2019
# 2        1.000000  2019
# 3        1.000000  2019
# 4        1.000000  2019
# ...           ...   ...
# 1460629  2.056718  2022
# 1460630  1.051158  2022
# 1460631  1.122392  2022
# 1460632  1.468439  2022
# 1460633  1.549911  2022
#
# [1460634 rows x 6 columns]

# %% [markdown]
# ## Filter by relevant rules (lift > 1.1)

# %%
relevant_rules_table_2019 = rules_table_2019.query("lift > 1.1")
relevant_rules_table_2020 = rules_table_2020.query("lift > 1.1")
relevant_rules_table_2021 = rules_table_2021.query("lift > 1.1")
relevant_rules_table_2022 = rules_table_2022.query("lift > 1.1")

print("2019: " + str(relevant_rules_table_2019['items_base'].count()))
print("2020: " + str(relevant_rules_table_2020['items_base'].count()))
print("2021: " + str(relevant_rules_table_2021['items_base'].count()))
print("2022: " + str(relevant_rules_table_2022['items_base'].count()))
# Out:
# 2019: 255215
# 2020: 414244
# 2021: 354631
# 2022: 236888

# %% [markdown]
# ## Recurring rules

# %%
intersec_pre_covid = pd.merge(relevant_rules_table_2019, relevant_rules_table_2020, how = 'inner', on = ['items_base', 'items_add'], suffixes=('_x', '_y'))
intersec_pos_covid = pd.merge(relevant_rules_table_2021, relevant_rules_table_2022, how = 'inner', on = ['items_base', 'items_add'], suffixes=('_x', '_y'))

# %% [markdown]
# ## Save results to a new CSV file

# %%
import os
intersec_pre_covid.to_csv('results/covid-analysis/intersection-pre-covid.csv')
intersec_pos_covid.to_csv('results/covid-analysis/intersection-pos-covid.csv')

# %% [markdown]
# ## View data of interest for pre-covid period

# %%
intersec_pre_covid.query("items_add.str.contains('NOTA: MUITO ACIMA DA MÉDIA')")
# Out:
#                                                items_base  \
# 3                                              ['Branco']
# 12                                    ['Classe Social C']
# 17                                    ['Classe Social D']
# 40                             ['Mãe Graduação completa']
# 43                         ['Mãe Pós-graduação completa']
# ...                                                   ...
# 239221  ['Região Sudeste', 'Branco', 'Solteiro(a)', 'T...
# 239228  ['Região Sudeste', 'Branco', 'Solteiro(a)', 'T...
# 239236  ['Solteiro(a)', 'Branco', 'Tem computador', 'J...
# 239244  ['Região Sudeste', 'Solteiro(a)', 'Tem computa...
# 239252  ['Região Sudeste', 'Branco', 'Solteiro(a)', 'T...
#
#                                                 items_add  support_x  \
# 3                          ['NOTA: MUITO ACIMA DA MÉDIA']   0.420352
# 12                         ['NOTA: MUITO ACIMA DA MÉDIA']   0.219298
# 17                         ['NOTA: MUITO ACIMA DA MÉDIA']   0.146098
# 40                         ['NOTA: MUITO ACIMA DA MÉDIA']   0.194682
# 43                         ['NOTA: MUITO ACIMA DA MÉDIA']   0.201946
# ...                                                   ...        ...
# 239221  ['Já concluí o Ensino Médio', 'NOTA: MUITO ACI...   0.110686
# 239228  ['NOTA: MUITO ACIMA DA MÉDIA', 'Entre 17 e 25 ...   0.110686
# 239236  ['NOTA: MUITO ACIMA DA MÉDIA', 'Dependencia ad...   0.110686
# 239244           ['Branco', 'NOTA: MUITO ACIMA DA MÉDIA']   0.110686
# 239252                     ['NOTA: MUITO ACIMA DA MÉDIA']   0.110686
#
#         confidence_x    lift_x  year_x  support_y  confidence_y    lift_y  \
# 3           0.851260  1.321009    2019   0.493427      0.903301  1.220094
# 12          0.973313  1.510415    2019   0.226795      0.986603  1.332610
# 17          0.888072  1.378136    2019   0.189362      0.932297  1.259259
# 40          0.933880  1.449222    2019   0.215782      0.948622  1.281308
# 43          0.954989  1.481979    2019   0.243557      0.967863  1.307298
# ...              ...       ...     ...        ...           ...       ...
# 239221      0.917392  2.400426    2019   0.144961      0.953484  1.941940
# 239228      0.916750  1.620421    2019   0.144961      0.929239  1.393431
# 239236      0.978440  2.049847    2019   0.144961      0.990210  1.830210
# 239244      0.691341  1.644673    2019   0.144961      0.724370  1.468039
# 239252      0.978440  1.518371    2019   0.144961      0.990210  1.337482
#
#         year_y
# 3         2020
# 12        2020
# 17        2020
# 40        2020
# 43        2020
# ...        ...
# 239221    2020
# 239228    2020
# 239236    2020
# 239244    2020
# 239252    2020
#
# [78104 rows x 10 columns]

# %%
intersec_pre_covid.query("items_add.str.contains('NOTA: MUITO ABAIXO DA MÉDIA')")
# Out:
#                                               items_base  \
# 21                                   ['Classe Social E']
# 47                                ['Não tem computador']
# 418    ['Classe Social E', 'Dependencia administrativ...
# 429            ['Classe Social E', 'Entre 17 e 25 anos']
# 443                      ['Feminino', 'Classe Social E']
# ...                                                  ...
# 51048  ['Não tem computador', 'Classe Social E', 'Ent...
# 51049  ['Não tem computador', 'Classe Social E', 'Ent...
# 51051  ['Não tem computador', 'Classe Social E', 'Tem...
# 51055  ['Não tem computador', 'Entre 17 e 25 anos', '...
# 51058  ['Solteiro(a)', 'Não tem computador', 'Entre 1...
#
#                                                items_add  support_x  \
# 21                       ['NOTA: MUITO ABAIXO DA MÉDIA']   0.330243
# 47                       ['NOTA: MUITO ABAIXO DA MÉDIA']   0.256183
# 418                      ['NOTA: MUITO ABAIXO DA MÉDIA']   0.217493
# 429                      ['NOTA: MUITO ABAIXO DA MÉDIA']   0.230479
# 443                      ['NOTA: MUITO ABAIXO DA MÉDIA']   0.189218
# ...                                                  ...        ...
# 51048     ['NOTA: MUITO ABAIXO DA MÉDIA', 'Tem celular']   0.157095
# 51049     ['NOTA: MUITO ABAIXO DA MÉDIA', 'Solteiro(a)']   0.157095
# 51051  ['NOTA: MUITO ABAIXO DA MÉDIA', 'Entre 17 e 25...   0.157095
# 51055  ['NOTA: MUITO ABAIXO DA MÉDIA', 'Classe Social...   0.157095
# 51058                    ['NOTA: MUITO ABAIXO DA MÉDIA']   0.157095
#
#        confidence_x    lift_x  year_x  support_y  confidence_y    lift_y  \
# 21         0.716345  2.014476    2019   0.242099      0.582680  2.244132
# 47         0.842617  2.369573    2019   0.192442      0.789964  3.042465
# 418        0.679807  1.911724    2019   0.186334      0.563080  2.168645
# 429        0.665412  1.871244    2019   0.161536      0.512227  1.972789
# 443        0.734292  2.064946    2019   0.138486      0.599882  2.310383
# ...             ...       ...     ...        ...           ...       ...
# 51048      0.834048  2.457668    2019   0.114626      0.771310  3.101354
# 51049      0.840052  2.756284    2019   0.114626      0.774735  3.527335
# 51051      0.696387  2.814475    2019   0.114626      0.632538  3.654292
# 51055      0.775716  2.348921    2019   0.114626      0.707359  2.921783
# 51058      0.886420  2.492753    2019   0.114626      0.813378  3.132641
#
#        year_y
# 21       2020
# 47       2020
# 418      2020
# 429      2020
# 443      2020
# ...       ...
# 51048    2020
# 51049    2020
# 51051    2020
# 51055    2020
# 51058    2020
#
# [255 rows x 10 columns]

# %% [markdown]
# ## Generate WordCloud for NOTAS MUITO ACIMA DA MÉDIA

# %%
all_high = intersec_pre_covid.query("items_add.str.contains('NOTA: MUITO ACIMA DA MÉDIA')")

xss = all_high['items_base'].to_numpy()
flat_list = [x for xs in xss for x in xs]

# Transform into a string compatible with WordCloud
words = ''.join(flat_list)

words = words.replace(" ", "").replace("[", "").replace("]", " ").replace("NãoRespondeu", "").replace(",", " ").replace("'", "").replace(":", "").replace(".", "").replace("-", "").replace("(", "").replace(")", "")

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width = 1200, height = 500,
                background_color ='white', colormap="Dark2",
                min_font_size = 10, collocations=False).generate(words)
                 
ax = plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

figure = ax.get_figure()

# %% [markdown]
# ## Generate WordCloud for NOTAS MUITO ABAIXO DA MÉDIA

# %%
all_low = intersec_pre_covid.query("items_add.str.contains('NOTA: MUITO ABAIXO DA MÉDIA')")

xss = all_low['items_base'].to_numpy()
flat_list = [x for xs in xss for x in xs]

# Transform into a string compatible with WordCloud
words2 = ''.join(flat_list)

words2 = words2.replace(" ", "").replace("[", "").replace("]", " ").replace("NãoRespondeu", "").replace(",", " ").replace("'", "").replace(":", "").replace(".", "").replace("-", "")

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width = 1200, height = 500,
                background_color ='white', colormap="Dark2",
                min_font_size = 10, collocations=False).generate(words2)
                    
ax = plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

figure = ax.get_figure()

# %% [markdown]
# ## View data of interest for pos-covid period

# %%
intersec_pos_covid.query("items_add.str.contains('NOTA: MUITO ACIMA DA MÉDIA')")
# Out:
#                                                items_base  \
# 3                                              ['Branco']
# 11                                    ['Classe Social C']
# 14                                    ['Classe Social D']
# 46                          ['Já concluí o Ensino Médio']
# 54                             ['Mãe Graduação completa']
# ...                                                   ...
# 172802  ['Solteiro(a)', 'Branco', 'Tem computador', 'J...
# 172809  ['Solteiro(a)', 'Branco', 'Tem computador', 'J...
# 172817  ['Solteiro(a)', 'Branco', 'Tem computador', 'J...
# 172826  ['Solteiro(a)', 'Tem computador', 'Já concluí ...
# 172832  ['Solteiro(a)', 'Branco', 'Tem computador', 'J...
#
#                                                 items_add  support_x  \
# 3                          ['NOTA: MUITO ACIMA DA MÉDIA']   0.453407
# 11                         ['NOTA: MUITO ACIMA DA MÉDIA']   0.215612
# 14                         ['NOTA: MUITO ACIMA DA MÉDIA']   0.154721
# 46                         ['NOTA: MUITO ACIMA DA MÉDIA']   0.427115
# 54                         ['NOTA: MUITO ACIMA DA MÉDIA']   0.191225
# ...                                                   ...        ...
# 172802         ['Feminino', 'NOTA: MUITO ACIMA DA MÉDIA']   0.146359
# 172809  ['NOTA: MUITO ACIMA DA MÉDIA', 'Entre 17 e 25 ...   0.146359
# 172817  ['NOTA: MUITO ACIMA DA MÉDIA', 'Dependencia ad...   0.146359
# 172826           ['Branco', 'NOTA: MUITO ACIMA DA MÉDIA']   0.146359
# 172832                     ['NOTA: MUITO ACIMA DA MÉDIA']   0.146359
#
#         confidence_x    lift_x  year_x  support_y  confidence_y    lift_y  \
# 3           0.838403  1.298055    2021   0.348986      0.739545  1.518887
# 11          0.958359  1.483775    2021   0.158446      0.944125  1.939057
# 14          0.842261  1.304028    2021   0.117142      0.784482  1.611180
# 46          0.799196  1.237352    2021   0.321955      0.684507  1.405849
# 54          0.902302  1.396986    2021   0.146007      0.839762  1.724713
# ...              ...       ...     ...        ...           ...       ...
# 172802      0.587135  1.685305    2021   0.111337      0.569036  2.224006
# 172809      0.920278  1.590580    2021   0.111337      0.907219  2.065577
# 172817      0.977646  2.074198    2021   0.111337      0.962302  2.701502
# 172826      0.682974  1.506317    2021   0.111337      0.673727  1.930530
# 172832      0.977646  1.513636    2021   0.111337      0.962302  1.976388
#
#         year_y
# 3         2022
# 11        2022
# 14        2022
# 46        2022
# 54        2022
# ...        ...
# 172802    2022
# 172809    2022
# 172817    2022
# 172826    2022
# 172832    2022
#
# [49156 rows x 10 columns]

# %%
intersec_pos_covid.query("items_add.str.contains('NOTA: MUITO ABAIXO DA MÉDIA')")
# Out:
#                                                items_base  \
# 20                                    ['Classe Social E']
# 38                                           ['Estadual']
# 59                                 ['Não tem computador']
# 61                                              ['Pardo']
# 62                                            ['Pública']
# ...                                                   ...
# 127092  ['Estou cursando e concluirei o Ensino este an...
# 127097  ['Solteiro(a)', 'Entre 17 e 25 anos', 'Classe ...
# 127101  ['Estou cursando e concluirei o Ensino este an...
# 127107  ['Estou cursando e concluirei o Ensino este an...
# 127111  ['Estou cursando e concluirei o Ensino este an...
#
#                                                 items_add  support_x  \
# 20                        ['NOTA: MUITO ABAIXO DA MÉDIA']   0.313478
# 38                        ['NOTA: MUITO ABAIXO DA MÉDIA']   0.112241
# 59                        ['NOTA: MUITO ABAIXO DA MÉDIA']   0.241015
# 61                        ['NOTA: MUITO ABAIXO DA MÉDIA']   0.195288
# 62                        ['NOTA: MUITO ABAIXO DA MÉDIA']   0.174274
# ...                                                   ...        ...
# 127092         ['Pública', 'NOTA: MUITO ABAIXO DA MÉDIA']   0.104487
# 127097  ['NOTA: MUITO ABAIXO DA MÉDIA', 'Estou cursand...   0.104487
# 127101  ['NOTA: MUITO ABAIXO DA MÉDIA', 'Entre 17 e 25...   0.104487
# 127107  ['NOTA: MUITO ABAIXO DA MÉDIA', 'Classe Social...   0.104487
# 127111                    ['NOTA: MUITO ABAIXO DA MÉDIA']   0.104487
#
#         confidence_x    lift_x  year_x  support_y  confidence_y    lift_y  \
# 20          0.710366  2.006073    2021   0.469317      0.821316  1.600692
# 38          0.896097  2.530577    2021   0.178954      0.960210  1.871388
# 59          0.882451  2.492039    2021   0.373082      0.929626  1.811780
# 61          0.583566  1.647989    2021   0.289127      0.740045  1.442300
# 62          0.773031  2.183037    2021   0.265086      0.890666  1.735850
# ...              ...       ...     ...        ...           ...       ...
# 127092      0.814608  4.674288    2021   0.174385      0.900630  3.397498
# 127097      0.883174  4.947738    2021   0.174385      0.952153  3.509623
# 127101      0.860997  3.267125    2021   0.174385      0.931907  2.291210
# 127107      0.626277  1.997837    2021   0.174385      0.789559  1.682357
# 127111      0.883174  2.494081    2021   0.174385      0.952153  1.855684
#
#         year_y
# 20        2022
# 38        2022
# 59        2022
# 61        2022
# 62        2022
# ...        ...
# 127092    2022
# 127097    2022
# 127101    2022
# 127107    2022
# 127111    2022
#
# [2757 rows x 10 columns]

# %% [markdown]
# ## Generate WordCloud for NOTAS MUITO ACIMA DA MÉDIA

# %%
all_high = intersec_pos_covid.query("items_add.str.contains('NOTA: MUITO ACIMA DA MÉDIA')")

xss = all_high['items_base'].to_numpy()
flat_list = [x for xs in xss for x in xs]

# Transform into a string compatible with WordCloud
words = ''.join(flat_list)

words = words.replace(" ", "").replace("[", "").replace("]", " ").replace("NãoRespondeu", "").replace(",", " ").replace("'", "").replace(":", "").replace(".", "").replace("-", "").replace("(", "").replace(")", "")

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width = 1200, height = 500,
                background_color ='white', colormap="Dark2",
                min_font_size = 10, collocations=False).generate(words)
                 
ax = plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

figure = ax.get_figure()

# %% [markdown]
# ## Generate WordCloud for NOTAS MUITO ABAIXO DA MÉDIA

# %%
all_low = intersec_pos_covid.query("items_add.str.contains('NOTA: MUITO ABAIXO DA MÉDIA')")

xss = all_low['items_base'].to_numpy()
flat_list = [x for xs in xss for x in xs]

# Transform into a string compatible with WordCloud
words2 = ''.join(flat_list)

words2 = words2.replace(" ", "").replace("[", "").replace("]", " ").replace("NãoRespondeu", "").replace(",", " ").replace("'", "").replace(":", "").replace(".", "").replace("-", "")

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width = 1200, height = 500,
                background_color ='white', colormap="Dark2",
                min_font_size = 10, collocations=False).generate(words2)
                    
ax = plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

figure = ax.get_figure()
