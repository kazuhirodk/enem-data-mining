# %% [markdown]
# # Analysis from ENEM microdata for 2020

# %% [markdown]
# ## Import libs

# %%
import pandas as pd
from apyori import apriori

# %% [markdown]
# ## Read microdata file

# %%
data = pd.read_csv('../microdata/microdata-enem-2020.csv', sep=';', encoding='ISO-8859-1')
data
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        200006271946    2020               11       F                1
# 1        200001195856    2020               11       M                2
# 2        200001943954    2020                4       F                2
# 3        200001908998    2020                2       M                1
# 4        200001634757    2020                4       F                1
# ...               ...     ...              ...     ...              ...
# 5783104  200003396891    2020                2       F                1
# 5783105  200006040822    2020                3       M                1
# 5783106  200004928656    2020                3       F                1
# 5783107  200006774808    2020                4       F                1
# 5783108  200007078230    2020                2       F                1
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 0                  2                 1                1               11
# 1                  3                 1                1               11
# 2                  3                 2                2                0
# 3                  3                 1                2                0
# 4                  3                 2                1                1
# ...              ...               ...              ...              ...
# 5783104            1                 1                2                0
# 5783105            1                 1                2                0
# 5783106            1                 1                1                1
# 5783107            1                 1                2                0
# 5783108            3                 1                2                0
#
#          TP_ESCOLA  ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  \
# 0                1  ...   NaN   NaN   NaN  NaN   NaN  NaN   NaN   NaN   NaN
# 1                1  ...   NaN   NaN   NaN  NaN   NaN  NaN   NaN   NaN   NaN
# 2                2  ...     B     A     A    B     A    A     A     A     A
# 3                2  ...   NaN   NaN   NaN  NaN   NaN  NaN   NaN   NaN   NaN
# 4                1  ...     A     A     A    B     A    B     B     A     A
# ...            ...  ...   ...   ...   ...  ...   ...  ...   ...   ...   ...
# 5783104          2  ...     B     A     A    B     A    A     D     A     B
# 5783105          2  ...   NaN   NaN   NaN  NaN   NaN  NaN   NaN   NaN   NaN
# 5783106          1  ...   NaN   NaN   NaN  NaN   NaN  NaN   NaN   NaN   NaN
# 5783107          3  ...     B     B     B    D     B    B     E     A     D
# 5783108          2  ...     A     A     A    B     B    A     D     A     A
#
#          Q025
# 0         NaN
# 1         NaN
# 2           A
# 3         NaN
# 4           B
# ...       ...
# 5783104     B
# 5783105   NaN
# 5783106   NaN
# 5783107     B
# 5783108     B
#
# [5783109 rows x 76 columns]

# %% [markdown]
# ## Select only columns of interest

# %%
interest_columns = [
    'TP_SEXO',
    'TP_ESTADO_CIVIL',
    'TP_COR_RACA',
    'TP_FAIXA_ETARIA',
    'TP_ST_CONCLUSAO',
    'TP_ESCOLA',
    'TP_DEPENDENCIA_ADM_ESC',
    'SG_UF_PROVA',
    'NU_NOTA_CN',
    'NU_NOTA_CH',
    'NU_NOTA_LC',
    'NU_NOTA_MT',
    'NU_NOTA_REDACAO',
    'Q001',
    'Q002',
    'Q006',
    'Q022',
    'Q024',
    'Q025'
]

interest_data = data[interest_columns]

interest_data.head()
# Out:
#   TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  TP_FAIXA_ETARIA  TP_ST_CONCLUSAO  \
# 0       F                1            2               11                1
# 1       M                2            3               11                1
# 2       F                2            3                4                2
# 3       M                1            3                2                2
# 4       F                1            3                4                1
#
#    TP_ESCOLA  TP_DEPENDENCIA_ADM_ESC SG_UF_PROVA  NU_NOTA_CN  NU_NOTA_CH  \
# 0          1                     NaN          PA         NaN         NaN
# 1          1                     NaN          RN       604.1       661.7
# 2          2                     2.0          BA         NaN         NaN
# 3          2                     3.0          SP       620.8       675.0
# 4          1                     NaN          MG         NaN         NaN
#
#    NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002 Q006 Q022 Q024 Q025
# 0         NaN         NaN              NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1       595.3       711.3            580.0  NaN  NaN  NaN  NaN  NaN  NaN
# 2         NaN         NaN              NaN    B    C    B    A    A    A
# 3       624.2       759.4            760.0  NaN  NaN  NaN  NaN  NaN  NaN
# 4         NaN         NaN              NaN    B    G    B    B    A    B

# %% [markdown]
# ### Check count for valid values

# %%
interest_data.count()
# Out:
# TP_SEXO                   5783109
# TP_ESTADO_CIVIL           5783109
# TP_COR_RACA               5783109
# TP_FAIXA_ETARIA           5783109
# TP_ST_CONCLUSAO           5783109
# TP_ESCOLA                 5783109
# TP_DEPENDENCIA_ADM_ESC     904569
# SG_UF_PROVA               5783109
# NU_NOTA_CN                2597440
# NU_NOTA_CH                2754140
# NU_NOTA_LC                2754140
# NU_NOTA_MT                2597440
# NU_NOTA_REDACAO           2754140
# Q001                      5687143
# Q002                      5687143
# Q006                      5687143
# Q022                      5687143
# Q024                      5687143
# Q025                      5687143
# dtype: int64

# %% [markdown]
# ## Translate some columns to better readability

# %%
# %run '../scripts/attribute-dictionary.py'

interest_data = interest_data.fillna(value = {"TP_DEPENDENCIA_ADM_ESC": 0})
interest_data = interest_data.replace(dictionary_params)

interest_data.head()
# Out:
#      TP_SEXO                       TP_ESTADO_CIVIL TP_COR_RACA  \
# 0   Feminino                           Solteiro(a)       Preto
# 1  Masculino  Casado(a) ou mora com companheiro(a)       Pardo
# 2   Feminino  Casado(a) ou mora com companheiro(a)       Pardo
# 3  Masculino                           Solteiro(a)       Pardo
# 4   Feminino                           Solteiro(a)       Pardo
#
#       TP_FAIXA_ETARIA                                TP_ST_CONCLUSAO  \
# 0  Entre 26 e 30 anos                      Já concluí o Ensino Médio
# 1  Entre 26 e 30 anos                      Já concluí o Ensino Médio
# 2  Entre 17 e 25 anos  Estou cursando e concluirei o Ensino este ano
# 3  Entre 17 e 25 anos  Estou cursando e concluirei o Ensino este ano
# 4  Entre 17 e 25 anos                      Já concluí o Ensino Médio
#
#        TP_ESCOLA                    TP_DEPENDENCIA_ADM_ESC      SG_UF_PROVA  \
# 0  Não Respondeu  Dependencia administrativa nao informada     Região Norte
# 1  Não Respondeu  Dependencia administrativa nao informada  Região Nordeste
# 2        Pública                                  Estadual  Região Nordeste
# 3        Pública                                 Municipal   Região Sudeste
# 4  Não Respondeu  Dependencia administrativa nao informada   Região Sudeste
#
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO  \
# 0         NaN         NaN         NaN         NaN              NaN
# 1       604.1       661.7       595.3       711.3            580.0
# 2         NaN         NaN         NaN         NaN              NaN
# 3       620.8       675.0       624.2       759.4            760.0
# 4         NaN         NaN         NaN         NaN              NaN
#
#                            Q001                           Q002  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2  Pai Fundamental I incompleto  Mãe Fundamental II incompleto
# 3                           NaN                            NaN
# 4  Pai Fundamental I incompleto     Mãe Pós-graduação completa
#
#               Q006             Q022                Q024  \
# 0              NaN              NaN                 NaN
# 1              NaN              NaN                 NaN
# 2  Classe Social E  Não tem celular  Não tem computador
# 3              NaN              NaN                 NaN
# 4  Classe Social E      Tem celular  Não tem computador
#
#                        Q025
# 0                       NaN
# 1                       NaN
# 2  Não tem internet em casa
# 3                       NaN
# 4      Tem internet em casa

# %% [markdown]
# ## Remove nil values and creates a new column with the arithmetic average of the grades

# %%
interest_data = interest_data.query("NU_NOTA_CN.notnull() and NU_NOTA_CH.notnull() and NU_NOTA_LC.notnull() and NU_NOTA_MT.notnull() and NU_NOTA_REDACAO.notnull() and TP_ESTADO_CIVIL.notnull() and Q006.notnull() and Q022.notnull() and Q024.notnull() and Q025.notnull()")
interest_data["NU_NOTA_GERAL"] = interest_data[["NU_NOTA_CN", "NU_NOTA_CH", "NU_NOTA_LC", "NU_NOTA_MT", "NU_NOTA_REDACAO"]].mean(axis=1)

interest_data.head()
# Out:
#       TP_SEXO                       TP_ESTADO_CIVIL TP_COR_RACA  \
# 5    Feminino                           Solteiro(a)       Pardo
# 8    Feminino  Casado(a) ou mora com companheiro(a)       Pardo
# 11  Masculino                           Solteiro(a)      Branco
# 18   Feminino                           Solteiro(a)       Pardo
# 19  Masculino                           Solteiro(a)       Preto
#
#        TP_FAIXA_ETARIA            TP_ST_CONCLUSAO      TP_ESCOLA  \
# 5   Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 8   Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 11  Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 18  Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 19  Entre 36 e 40 anos  Já concluí o Ensino Médio  Não Respondeu
#
#                       TP_DEPENDENCIA_ADM_ESC      SG_UF_PROVA  NU_NOTA_CN  \
# 5   Dependencia administrativa nao informada       Região Sul       498.1
# 8   Dependencia administrativa nao informada  Região Nordeste       439.7
# 11  Dependencia administrativa nao informada  Região Nordeste       491.1
# 18  Dependencia administrativa nao informada  Região Nordeste       422.4
# 19  Dependencia administrativa nao informada     Região Norte       486.0
#
#     NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO  \
# 5        604.7       505.4       526.7            700.0
# 8        383.5       486.2       448.5            600.0
# 11       631.4       627.9       546.5            640.0
# 18       488.1       559.1       420.3            800.0
# 19       503.3       439.8       405.6            500.0
#
#                              Q001                           Q002  \
# 5   Pai Fundamental II incompleto   Mãe Fundamental I incompleto
# 8    Pai Fundamental I incompleto  Mãe Fundamental II incompleto
# 11   Pai Fundamental I incompleto  Mãe Fundamental II incompleto
# 18  Pai Fundamental II incompleto  Mãe Fundamental II incompleto
# 19  Pai Fundamental II incompleto    Mãe Ensino médio incompleto
#
#                Q006         Q022                Q024  \
# 5   Classe Social E  Tem celular      Tem computador
# 8   Classe Social E  Tem celular  Não tem computador
# 11  Classe Social E  Tem celular      Tem computador
# 18  Classe Social E  Tem celular      Tem computador
# 19  Classe Social E  Tem celular  Não tem computador
#
#                         Q025  NU_NOTA_GERAL
# 5       Tem internet em casa         566.98
# 8   Não tem internet em casa         471.58
# 11      Tem internet em casa         587.38
# 18      Tem internet em casa         537.98
# 19  Não tem internet em casa         466.94

# %% [markdown]
# ### Check count for valid values

# %%
interest_data.count()
# Out:
# TP_SEXO                   2561304
# TP_ESTADO_CIVIL           2561304
# TP_COR_RACA               2561304
# TP_FAIXA_ETARIA           2561304
# TP_ST_CONCLUSAO           2561304
# TP_ESCOLA                 2561304
# TP_DEPENDENCIA_ADM_ESC    2561304
# SG_UF_PROVA               2561304
# NU_NOTA_CN                2561304
# NU_NOTA_CH                2561304
# NU_NOTA_LC                2561304
# NU_NOTA_MT                2561304
# NU_NOTA_REDACAO           2561304
# Q001                      2561304
# Q002                      2561304
# Q006                      2561304
# Q022                      2561304
# Q024                      2561304
# Q025                      2561304
# NU_NOTA_GERAL             2561304
# dtype: int64

# %% [markdown]
# ## Calculate Z-SCORE from NU_NOTA_GERAL

# %%
from scipy.stats import zscore

interest_data["Z_SCORE_NOTA"] = zscore(interest_data["NU_NOTA_GERAL"])
interest_data.head()
# Out:
#       TP_SEXO                       TP_ESTADO_CIVIL TP_COR_RACA  \
# 5    Feminino                           Solteiro(a)       Pardo
# 8    Feminino  Casado(a) ou mora com companheiro(a)       Pardo
# 11  Masculino                           Solteiro(a)      Branco
# 18   Feminino                           Solteiro(a)       Pardo
# 19  Masculino                           Solteiro(a)       Preto
#
#        TP_FAIXA_ETARIA            TP_ST_CONCLUSAO      TP_ESCOLA  \
# 5   Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 8   Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 11  Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 18  Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 19  Entre 36 e 40 anos  Já concluí o Ensino Médio  Não Respondeu
#
#                       TP_DEPENDENCIA_ADM_ESC      SG_UF_PROVA  NU_NOTA_CN  \
# 5   Dependencia administrativa nao informada       Região Sul       498.1
# 8   Dependencia administrativa nao informada  Região Nordeste       439.7
# 11  Dependencia administrativa nao informada  Região Nordeste       491.1
# 18  Dependencia administrativa nao informada  Região Nordeste       422.4
# 19  Dependencia administrativa nao informada     Região Norte       486.0
#
#     NU_NOTA_CH  ...  NU_NOTA_MT  NU_NOTA_REDACAO  \
# 5        604.7  ...       526.7            700.0
# 8        383.5  ...       448.5            600.0
# 11       631.4  ...       546.5            640.0
# 18       488.1  ...       420.3            800.0
# 19       503.3  ...       405.6            500.0
#
#                              Q001                           Q002  \
# 5   Pai Fundamental II incompleto   Mãe Fundamental I incompleto
# 8    Pai Fundamental I incompleto  Mãe Fundamental II incompleto
# 11   Pai Fundamental I incompleto  Mãe Fundamental II incompleto
# 18  Pai Fundamental II incompleto  Mãe Fundamental II incompleto
# 19  Pai Fundamental II incompleto    Mãe Ensino médio incompleto
#
#                Q006         Q022                Q024  \
# 5   Classe Social E  Tem celular      Tem computador
# 8   Classe Social E  Tem celular  Não tem computador
# 11  Classe Social E  Tem celular      Tem computador
# 18  Classe Social E  Tem celular      Tem computador
# 19  Classe Social E  Tem celular  Não tem computador
#
#                         Q025 NU_NOTA_GERAL  Z_SCORE_NOTA
# 5       Tem internet em casa        566.98      0.441210
# 8   Não tem internet em casa        471.58     -0.601147
# 11      Tem internet em casa        587.38      0.664104
# 18      Tem internet em casa        537.98      0.124351
# 19  Não tem internet em casa        466.94     -0.651844
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Z-SCORE mínimo

# %%
interest_data["Z_SCORE_NOTA"].min()
# Out:
# -5.753708555170386

# %% [markdown]
# ### Z-SCORE máximo

# %%
interest_data["Z_SCORE_NOTA"].max()
# Out:
# 3.627280109866742

# %% [markdown]
# ## Create a label for grade based on z-score

# %%
NOTA_GERAL_LABELS = [
  "NOTA: MUITO ABAIXO DA MÉDIA",
  "NOTA: ABAIXO DA MÉDIA",
  "NOTA: MÉDIA",
  "NOTA: ACIMA DA MÉDIA",
  "NOTA: MUITO ACIMA DA MÉDIA",
]

interest_data["CLASSIFICACAO_NOTA"] = pd.cut(interest_data["Z_SCORE_NOTA"], bins=[-10, -2, -1, 1, 2, 10], labels=NOTA_GERAL_LABELS)

interest_data.head()
# Out:
#       TP_SEXO                       TP_ESTADO_CIVIL TP_COR_RACA  \
# 5    Feminino                           Solteiro(a)       Pardo
# 8    Feminino  Casado(a) ou mora com companheiro(a)       Pardo
# 11  Masculino                           Solteiro(a)      Branco
# 18   Feminino                           Solteiro(a)       Pardo
# 19  Masculino                           Solteiro(a)       Preto
#
#        TP_FAIXA_ETARIA            TP_ST_CONCLUSAO      TP_ESCOLA  \
# 5   Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 8   Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 11  Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 18  Entre 17 e 25 anos  Já concluí o Ensino Médio  Não Respondeu
# 19  Entre 36 e 40 anos  Já concluí o Ensino Médio  Não Respondeu
#
#                       TP_DEPENDENCIA_ADM_ESC      SG_UF_PROVA  NU_NOTA_CN  \
# 5   Dependencia administrativa nao informada       Região Sul       498.1
# 8   Dependencia administrativa nao informada  Região Nordeste       439.7
# 11  Dependencia administrativa nao informada  Região Nordeste       491.1
# 18  Dependencia administrativa nao informada  Região Nordeste       422.4
# 19  Dependencia administrativa nao informada     Região Norte       486.0
#
#     NU_NOTA_CH  ...  NU_NOTA_REDACAO                           Q001  \
# 5        604.7  ...            700.0  Pai Fundamental II incompleto
# 8        383.5  ...            600.0   Pai Fundamental I incompleto
# 11       631.4  ...            640.0   Pai Fundamental I incompleto
# 18       488.1  ...            800.0  Pai Fundamental II incompleto
# 19       503.3  ...            500.0  Pai Fundamental II incompleto
#
#                              Q002             Q006         Q022  \
# 5    Mãe Fundamental I incompleto  Classe Social E  Tem celular
# 8   Mãe Fundamental II incompleto  Classe Social E  Tem celular
# 11  Mãe Fundamental II incompleto  Classe Social E  Tem celular
# 18  Mãe Fundamental II incompleto  Classe Social E  Tem celular
# 19    Mãe Ensino médio incompleto  Classe Social E  Tem celular
#
#                   Q024                      Q025 NU_NOTA_GERAL Z_SCORE_NOTA  \
# 5       Tem computador      Tem internet em casa        566.98     0.441210
# 8   Não tem computador  Não tem internet em casa        471.58    -0.601147
# 11      Tem computador      Tem internet em casa        587.38     0.664104
# 18      Tem computador      Tem internet em casa        537.98     0.124351
# 19  Não tem computador  Não tem internet em casa        466.94    -0.651844
#
#     CLASSIFICACAO_NOTA
# 5          NOTA: MÉDIA
# 8          NOTA: MÉDIA
# 11         NOTA: MÉDIA
# 18         NOTA: MÉDIA
# 19         NOTA: MÉDIA
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Check for uniqueness of all values to check if all of them was translated

# %%
interest_data['TP_SEXO'].unique()
# Out:
# array(['Feminino', 'Masculino'], dtype=object)

# %%
interest_data['TP_ESTADO_CIVIL'].unique()
# Out:
# array(['Solteiro(a)', 'Casado(a) ou mora com companheiro(a)',
#        'Estado civil: Não informado',
#        'Divorciado(a)/Desquitado(a)/Separado(a)', 'Viúvo(a)'],
#       dtype=object)

# %%
interest_data['TP_COR_RACA'].unique()
# Out:
# array(['Pardo', 'Branco', 'Preto', 'Cor/Raça Não Declarado', 'Amarelo',
#        'Indígena'], dtype=object)

# %%
interest_data['TP_FAIXA_ETARIA'].unique()
# Out:
# array(['Entre 17 e 25 anos', 'Entre 36 e 40 anos', 'Entre 31 e 35 anos',
#        'Entre 26 e 30 anos', 'Menor de 17 anos', 'Entre 46 e 50 anos',
#        'Entre 41 e 45 anos', 'Entre 51 e 55 anos', 'Entre 56 e 60 anos',
#        'Entre 66 e 70 anos', 'Entre 61 e 65 anos', 'Maior de 70 anos'],
#       dtype=object)

# %%
interest_data['TP_ST_CONCLUSAO'].unique()
# Out:
# array(['Já concluí o Ensino Médio',
#        'Estou cursando e concluirei o Ensino este ano',
#        'Estou cursando e concluirei o Ensino Médio após este ano',
#        'Não concluí e não estou cursando o Ensino Médio'], dtype=object)

# %%
interest_data['TP_ESCOLA'].unique()
# Out:
# array(['Não Respondeu', 'Pública', 'Privada'], dtype=object)

# %%
interest_data['TP_DEPENDENCIA_ADM_ESC'].unique()
# Out:
# array(['Dependencia administrativa nao informada', 'Estadual', 'Federal',
#        'Privada', 'Municipal'], dtype=object)

# %%
interest_data['SG_UF_PROVA'].unique()
# Out:
# array(['Região Sul', 'Região Nordeste', 'Região Norte', 'Região Sudeste',
#        'Região Centro-Oeste'], dtype=object)

# %%
interest_data['Q001'].unique()
# Out:
# array(['Pai Fundamental II incompleto', 'Pai Fundamental I incompleto',
#        'Pai Ensino médio completo', 'Pai Ensino médio incompleto',
#        'Não sei a escolaridade do meu pai', 'Pai nunca estudou',
#        'Pai Graduação completa', 'Pai Pós-graduação completa'],
#       dtype=object)

# %%
interest_data['Q002'].unique()
# Out:
# array(['Mãe Fundamental I incompleto', 'Mãe Fundamental II incompleto',
#        'Mãe Ensino médio incompleto', 'Mãe Ensino médio completo',
#        'Mãe nunca estudou', 'Mãe Graduação completa',
#        'Não sei a escolaridade da minha mãe',
#        'Mãe Pós-graduação completa'], dtype=object)

# %%
interest_data['Q006'].unique()
# Out:
# array(['Classe Social E', 'Classe Social D', 'Classe Social C',
#        'Classe Social B', 'Classe Social A'], dtype=object)

# %%
interest_data['Q022'].unique()
# Out:
# array(['Tem celular', 'Não tem celular'], dtype=object)

# %%
interest_data['Q024'].unique()
# Out:
# array(['Tem computador', 'Não tem computador'], dtype=object)

# %%
interest_data['Q025'].unique()
# Out:
# array(['Tem internet em casa', 'Não tem internet em casa'], dtype=object)

# %%
interest_data['CLASSIFICACAO_NOTA'].unique()
# Out:
# ['NOTA: MÉDIA', 'NOTA: MUITO ACIMA DA MÉDIA', 'NOTA: ABAIXO DA MÉDIA', 'NOTA: ACIMA DA MÉDIA', 'NOTA: MUITO ABAIXO DA MÉDIA']
# Categories (5, object): ['NOTA: MUITO ABAIXO DA MÉDIA' < 'NOTA: ABAIXO DA MÉDIA' < 'NOTA: MÉDIA' < 'NOTA: ACIMA DA MÉDIA' < 'NOTA: MUITO ACIMA DA MÉDIA']

# %% [markdown]
# ## Generate histograms by grade z-score

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

data = interest_data['Z_SCORE_NOTA'].to_numpy()

mu, std = norm.fit(data) 
  
# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k', linewidth=2)
  
plt.show()

# %% [markdown]
# ## Generate histograms by grade

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

data = interest_data['NU_NOTA_GERAL'].to_numpy()

mu, std = norm.fit(data) 
  
# Plot the histogram.
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
  
# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
  
plt.plot(x, p, 'k', linewidth=2)
  
plt.show()

# %% [markdown]
# ## Filter by grades far above or far below average

# %%
filtered_interest_data = interest_data.query("Z_SCORE_NOTA > 2.00 or Z_SCORE_NOTA < -2.00")
filtered_interest_data.count()
# Out:
# TP_SEXO                   117225
# TP_ESTADO_CIVIL           117225
# TP_COR_RACA               117225
# TP_FAIXA_ETARIA           117225
# TP_ST_CONCLUSAO           117225
# TP_ESCOLA                 117225
# TP_DEPENDENCIA_ADM_ESC    117225
# SG_UF_PROVA               117225
# NU_NOTA_CN                117225
# NU_NOTA_CH                117225
# NU_NOTA_LC                117225
# NU_NOTA_MT                117225
# NU_NOTA_REDACAO           117225
# Q001                      117225
# Q002                      117225
# Q006                      117225
# Q022                      117225
# Q024                      117225
# Q025                      117225
# NU_NOTA_GERAL             117225
# Z_SCORE_NOTA              117225
# CLASSIFICACAO_NOTA        117225
# dtype: int64

# %%
analysis_interest_columns = [
    'TP_SEXO',
    'TP_ESTADO_CIVIL',
    'TP_COR_RACA',
    'TP_FAIXA_ETARIA',
    'TP_ST_CONCLUSAO',
    'TP_ESCOLA',
    'TP_DEPENDENCIA_ADM_ESC',
    'SG_UF_PROVA',
    'CLASSIFICACAO_NOTA',
    'Q001',
    'Q002',
    'Q006',
    'Q022',
    'Q024',
    'Q025'
]

analysis_interest_data = filtered_interest_data[analysis_interest_columns]

# %% [markdown]
# ## Save a CSV file with the analysis interest data

# %%
import os  

os.makedirs('analysis_interest_data', exist_ok=True)  
analysis_interest_data.to_csv('analysis_interest_data/analysis-interest-data-2020.csv')

analysis_file_data = pd.read_csv('analysis_interest_data/analysis-interest-data-2020.csv', sep=',', encoding='UTF-8')
analysis_file_data.head()
# Out:
#    Unnamed: 0    TP_SEXO TP_ESTADO_CIVIL TP_COR_RACA     TP_FAIXA_ETARIA  \
# 0          22   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 1          47   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 2          76   Feminino     Solteiro(a)      Branco  Entre 17 e 25 anos
# 3         254   Feminino     Solteiro(a)       Pardo  Entre 17 e 25 anos
# 4         259  Masculino     Solteiro(a)      Branco  Entre 17 e 25 anos
#
#                                  TP_ST_CONCLUSAO      TP_ESCOLA  \
# 0                      Já concluí o Ensino Médio  Não Respondeu
# 1                      Já concluí o Ensino Médio  Não Respondeu
# 2                      Já concluí o Ensino Médio  Não Respondeu
# 3  Estou cursando e concluirei o Ensino este ano        Pública
# 4  Estou cursando e concluirei o Ensino este ano        Pública
#
#                      TP_DEPENDENCIA_ADM_ESC      SG_UF_PROVA  \
# 0  Dependencia administrativa nao informada     Região Norte
# 1  Dependencia administrativa nao informada  Região Nordeste
# 2  Dependencia administrativa nao informada   Região Sudeste
# 3  Dependencia administrativa nao informada  Região Nordeste
# 4  Dependencia administrativa nao informada   Região Sudeste
#
#            CLASSIFICACAO_NOTA                           Q001  \
# 0  NOTA: MUITO ACIMA DA MÉDIA      Pai Ensino médio completo
# 1  NOTA: MUITO ACIMA DA MÉDIA      Pai Ensino médio completo
# 2  NOTA: MUITO ACIMA DA MÉDIA      Pai Ensino médio completo
# 3  NOTA: MUITO ACIMA DA MÉDIA      Pai Ensino médio completo
# 4  NOTA: MUITO ACIMA DA MÉDIA  Pai Fundamental II incompleto
#
#                             Q002             Q006         Q022  \
# 0      Mãe Ensino médio completo  Classe Social E  Tem celular
# 1  Mãe Fundamental II incompleto  Classe Social E  Tem celular
# 2         Mãe Graduação completa  Classe Social E  Tem celular
# 3         Mãe Graduação completa  Classe Social E  Tem celular
# 4  Mãe Fundamental II incompleto  Classe Social E  Tem celular
#
#                  Q024                      Q025
# 0      Tem computador  Não tem internet em casa
# 1      Tem computador      Tem internet em casa
# 2      Tem computador      Tem internet em casa
# 3  Não tem computador      Tem internet em casa
# 4      Tem computador      Tem internet em casa

# %% [markdown]
# ## Convert table to transactions

# %%
transactions = analysis_interest_data.to_numpy()
transactions
# Out:
# array([['Feminino', 'Solteiro(a)', 'Pardo', ..., 'Tem celular',
#         'Tem computador', 'Não tem internet em casa'],
#        ['Feminino', 'Solteiro(a)', 'Pardo', ..., 'Tem celular',
#         'Tem computador', 'Tem internet em casa'],
#        ['Feminino', 'Solteiro(a)', 'Branco', ..., 'Tem celular',
#         'Tem computador', 'Tem internet em casa'],
#        ...,
#        ['Feminino', 'Solteiro(a)', 'Pardo', ..., 'Não tem celular',
#         'Não tem computador', 'Não tem internet em casa'],
#        ['Feminino', 'Solteiro(a)', 'Preto', ..., 'Tem celular',
#         'Não tem computador', 'Não tem internet em casa'],
#        ['Masculino', 'Solteiro(a)', 'Branco', ..., 'Tem celular',
#         'Tem computador', 'Tem internet em casa']], dtype=object)

# %% [markdown]
# ## Create apriori rules

# %%
# %run '../scripts/apriori-params-setup.py'
rules = apriori(transactions, min_support=support, min_confidence=confidence)
rules
# Out:
# <generator object apriori at 0x32e7f1cf0>

# %% [markdown]
# ## Run apriori

# %%
from datetime import datetime

initial_time = datetime.now()

results = pd.DataFrame(list(rules))

execution_time = datetime.now() - initial_time
print("Time to run apriori: " + str(execution_time))
# Out:
# Time to run apriori: 1:53:22.952846

# %%
results
# Out:
#                                                    items   support  \
# 0                                               (Branco)  0.546249
# 1             (Dependencia administrativa nao informada)  0.740439
# 2                                   (Entre 17 e 25 anos)  0.839966
# 3                                             (Feminino)  0.545916
# 4                            (Já concluí o Ensino Médio)  0.609554
# ...                                                  ...       ...
# 13068  (Tem celular, Entre 17 e 25 anos, Tem computad...  0.117356
# 13069  (Tem celular, Entre 17 e 25 anos, Tem computad...  0.158490
# 13070  (Tem celular, Entre 17 e 25 anos, Tem computad...  0.104892
# 13071  (Tem celular, Entre 17 e 25 anos, Tem computad...  0.144961
# 13072  (Tem celular, Entre 17 e 25 anos, Tem computad...  0.117356
#
#                                       ordered_statistics
# 0              [((), (Branco), 0.5462486670931969, 1.0)]
# 1      [((), (Dependencia administrativa nao informad...
# 2      [((), (Entre 17 e 25 anos), 0.8399658775858392...
# 3             [((), (Feminino), 0.545915973555129, 1.0)]
# 4      [((), (Já concluí o Ensino Médio), 0.609554275...
# ...                                                  ...
# 13068  [((Região Sudeste, Feminino), (Tem celular, En...
# 13069  [((Feminino, Branco), (Tem celular, Entre 17 e...
# 13070  [((Masculino, Dependencia administrativa nao i...
# 13071  [((Região Sudeste, Branco), (Tem celular, Entr...
# 13072  [((Região Sudeste, Feminino), (Tem celular, En...
#
# [13073 rows x 3 columns]

# %% [markdown]
# ## Extract results to a new table

# %%
from datetime import datetime

initial_time = datetime.now()

# %run '../scripts/extractor.py'

organized_rules = extractor(results)

execution_time = datetime.now() - initial_time
print("Time to run extractor: " + str(execution_time))

organized_rules
# Out:
# Time to run extractor: 0:00:06.308802
#                                                items_base  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 485071  [Tem celular, Entre 17 e 25 anos, Tem computad...
# 485072  [Tem celular, Entre 17 e 25 anos, Tem computad...
# 485073  [Tem celular, Entre 17 e 25 anos, Tem computad...
# 485074  [Tem celular, Tem computador, NOTA: MUITO ACIM...
# 485075  [Tem celular, Entre 17 e 25 anos, Tem computad...
#
#                                          items_add   support  confidence  \
# 0                                         [Branco]  0.546249    0.546249
# 1       [Dependencia administrativa nao informada]  0.740439    0.740439
# 2                             [Entre 17 e 25 anos]  0.839966    0.839966
# 3                                       [Feminino]  0.545916    0.545916
# 4                      [Já concluí o Ensino Médio]  0.609554    0.609554
# ...                                            ...       ...         ...
# 485071                [NOTA: MUITO ACIMA DA MÉDIA]  0.117356    0.984260
# 485072                 [Já concluí o Ensino Médio]  0.117356    0.974154
# 485073                                  [Feminino]  0.117356    0.599120
# 485074                        [Entre 17 e 25 anos]  0.117356    0.949020
# 485075  [Dependencia administrativa nao informada]  0.117356    1.000000
#
#             lift
# 0       1.000000
# 1       1.000000
# 2       1.000000
# 3       1.000000
# 4       1.000000
# ...          ...
# 485071  1.329445
# 485072  1.598141
# 485073  1.097459
# 485074  1.129832
# 485075  1.350550
#
# [485076 rows x 5 columns]

# %%
rules_count = len(organized_rules.index)
print("Count of itemsets: " + str(len(results.index)))
print("Count of association rules for support " + str((support *100)) + "% and confidence " + str((confidence * 100)) + "%: " + str(rules_count))
# Out:
# Count of itemsets: 13073
# Count of association rules for support 10.0% and confidence 50.0%: 485076

# %% [markdown]
# ## Save results to a new CSV file

# %%
import os  

os.makedirs('results', exist_ok=True)  
organized_rules.to_csv('results/organized-associations-2020.csv')
